# %% [markdown]
# # PyCS Tutorial
#
# In this notebook we work through the `PyCS` "demo1" tutorial, to show how the `PyCS` package enables the estimation of a lens time delay from example light curve data. The original tutorial is in the form of a set of 6 scripts, that can be viewed on the `PyCS` website [here](http://pycs.readthedocs.io/en/latest/tutorial/demo1.html). The demo1 code itself can be browsed in the `PyCS` GitHub repository [here](https://github.com/COSMOGRAIL/PyCS/tree/master/demo/demo1).

# %% [markdown]
# ## 1. Obtaining PyCS and its Sample Data
#
# The "demo1" tutorial uses a 4-image light curve dataset that comes with the `PyCS` repository. Let's download this and use `PyCS` to analyze it. If you haven't yet followed the [`SLTimer` installation instructions](https://github.com/DarkEnergyScienceCollaboration/SLTimer/blob/master/INSTALL.md) you should do that before attempting to `import pycs`.

# %%
import os, urllib
from __future__ import print_function
import pycs
# %matplotlib inline

# %% [markdown]
# We need to grab `rdbfile` (the demo1 dataset) from `webdir` (the appropriate `PyCS` GitHub folder). We only need to download `rdbfile` if it doesn't already exist.

# %%
webdir = 'https://raw.githubusercontent.com/COSMOGRAIL/PyCS/master/demo/demo1/data/'
rdbfile = 'trialcurves.txt'
    
url = os.path.join(webdir, rdbfile)
if not os.path.isfile(rdbfile):
    urllib.urlretrieve(url, rdbfile)
    
# !wc -l $rdbfile
# Out:
#      194 trialcurves.txt

# %% [markdown]
# ## 2. Displaying the Light Curve Data

# %% [markdown]
# First lets read in the data from the rdbfile, in this case from a simple text file with a one-line header. (Other formats are supported as well.)

# %%
lcs = [
        pycs.gen.lc.rdbimport(rdbfile, 'A', 'mag_A', 'magerr_A', "Trial"),
        pycs.gen.lc.rdbimport(rdbfile, 'B', 'mag_B', 'magerr_B', "Trial"),
        pycs.gen.lc.rdbimport(rdbfile, 'C', 'mag_C', 'magerr_C', "Trial"),
        pycs.gen.lc.rdbimport(rdbfile, 'D', 'mag_D', 'magerr_D', "Trial")
]
# Out:
# Checking header of "trialcurves.txt"...
# Reading "trialcurves.txt"...
# [Trial/A] with 192 points imported (0 of them masked).
# Checking header of "trialcurves.txt"...
# Reading "trialcurves.txt"...
# [Trial/B] with 192 points imported (0 of them masked).
# Checking header of "trialcurves.txt"...
# Reading "trialcurves.txt"...
# [Trial/C] with 192 points imported (0 of them masked).
# Checking header of "trialcurves.txt"...
# Reading "trialcurves.txt"...
# [Trial/D] with 192 points imported (0 of them masked).

# %%
pycs.gen.lc.display(lcs)

# %%
pycs.gen.sea.easycut(lcs, keep=(1, 2))
pycs.gen.lc.display(lcs)

# %%
l=lcs[0]
testl = l.copy() # Makes a full deep copy of the entire lightcurve objects, with all properties, labels, mask, etc.
testl.plotcolour = "blue"
testl.shiftflux(5000)
testl.mask = testl.magerrs < 0.01
pycs.gen.lc.display([l,testl])

# %%
lcs[1].shifttime(-5.0)
lcs[2].shifttime(-20.0)
lcs[3].shifttime(-70.0)

# %% [markdown]
# Now to display our plot!

# %%
pycs.gen.lc.display(lcs, figsize=(20, 7), jdrange=(53900, 55500))

# %% [markdown]
# To save this figure to a file:

# %%
pycs.gen.lc.display(lcs, filename="fig_trialcurves_true-shifted.pdf")
# Out:
# Plot written to fig_trialcurves_true-shifted.pdf

# %% [markdown]
# It's useful to store the lightcurve objects in a pickle for easy re-starting - here's the function for doing that:

# %%
pycs.gen.util.writepickle(lcs, "trialcurves_true-shifted.pkl")
# Out:
# Wrote trialcurves_true-shifted.pkl

# %% [markdown]
# In further scripts, you can now import the data by reading this file.

# %%
lcs = pycs.gen.util.readpickle("trialcurves_true-shifted.pkl")
# Out:
# Read trialcurves_true-shifted.pkl

# %% [markdown]
# We will now undo these shifts, and from now on we will "forget" about the true delays.

# %%
for l in lcs:
        l.resetshifts()

# %% [markdown]
# You can do a variety of things with this file to find out more information. For example, the `longinfo()` method will provide you with the number of points, gap length, shifts, median, mean, maximum, minimum, and the colour it is plotted in.

# %%
for l in lcs: print(l.longinfo())
# Out:
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 	[Trial/A]
# 192 points (total), 0 of which are masked
# 4 seasons (gap: >60), gap length : 164.0 +/- 33.8 days
# Sampling : median 4.0, mean 4.4, max 25.1, min 0.83 days
# Shifts : (0.00000,0.00000,0.00) [days, mag, flux]
# Colour : red
# Common properties :
#    All properties :
# Comments :
#    Imported from trialcurves.txt, columns (1, 2, 3)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 	[Trial/B]
# 192 points (total), 0 of which are masked
# 4 seasons (gap: >60), gap length : 164.0 +/- 33.8 days
# Sampling : median 4.0, mean 4.4, max 25.1, min 0.83 days
# Shifts : (0.00000,0.00000,0.00) [days, mag, flux]
# Colour : blue
# Common properties :
#    All properties :
# Comments :
#    Imported from trialcurves.txt, columns (1, 4, 5)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 	[Trial/C]
# 192 points (total), 0 of which are masked
# 4 seasons (gap: >60), gap length : 164.0 +/- 33.8 days
# Sampling : median 4.0, mean 4.4, max 25.1, min 0.83 days
# Shifts : (0.00000,0.00000,0.00) [days, mag, flux]
# Colour : #009900
# Common properties :
#    All properties :
# Comments :
#    Imported from trialcurves.txt, columns (1, 6, 7)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 	[Trial/D]
# 192 points (total), 0 of which are masked
# 4 seasons (gap: >60), gap length : 164.0 +/- 33.8 days
# Sampling : median 4.0, mean 4.4, max 25.1, min 0.83 days
# Shifts : (0.00000,0.00000,0.00) [days, mag, flux]
# Colour : purple
# Common properties :
#    All properties :
# Comments :
#    Imported from trialcurves.txt, columns (1, 8, 9)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# Another thing we can do is export the data into a text file called "out_trialcurves.txt". In this case, since we have not altered the original data, this file will contain the same information as trialcurves.txt.

# %%
pycs.gen.util.multilcsexport(lcs, "out_trialcurves.txt", separator="\t", verbose=True, properties=None)
# Out:
# [Trial/A]
# [Trial/B]
# [Trial/C]
# [Trial/D]
# Wrote the lightcurves into out_trialcurves.txt

# %% [markdown]
# ## 3. Fitting the Light Curves with a Free-Knot Spline Model

# %% [markdown]
# Let's now fit a spline model to our lightcurve data. At first we'll ignore microlensing and just set up a single spline curve to capture the intrinsic AGN variability. Then we'll add in additional curves to model the microlensing, and refine the fit.

# %% [markdown]
# ### 3.1 Basic Fit
#
# `PyCS` contains library functions for optimizing such a model, but the optimization has to be carried out according to a user-defined schedule. Shown here is a simple attempt to get a multi-purpose schedule for optimizing a free-knot spline model: we optimize the spline three times, twice roughly with two different knotsteps, and then once to fine-tune the parameters.

# %%
 def spl(lcs):
    spline = pycs.spl.topopt.opt_rough(lcs, nit=5, knotstep=50)
    for l in lcs:
        l.resetml()
    spline = pycs.spl.topopt.opt_rough(lcs, nit=5, knotstep=30)
    spline = pycs.spl.topopt.opt_fine(lcs, nit=10, knotstep=20)
    return spline

# %% [markdown]
# This optimization function (and each subroutine it calls) returns a `spline` object.

# %%
spline = spl(lcs)
# Out:
# Starting opt_rough on initial delays :
# AB   +0.00 | AC   +0.00 | AD   +0.00 | BC   +0.00 | BD   +0.00 | CD   +0.00
# Aiming at curves A, B, C, D.
# Starting ML optimization ...
# Done !
# First spline and ML opt done.
# AB  +18.00 | AC   -8.00 | AD  -15.00 | BC  -26.00 | BD  -33.00 | CD   -7.00    (Iteration  1, r2 =  70277.1)
# AB  +24.00 | AC   +6.00 | AD  -15.00 | BC  -18.00 | BD  -39.00 | CD  -21.00    (Iteration  2, r2 =  68832.7)
# AB  +28.00 | AC  +13.00 | AD  -11.00 | BC  -15.00 | BD  -39.00 | CD  -24.00    (Iteration  3, r2 =  68377.2)
# AB  +30.00 | AC  +16.00 | AD  -10.00 | BC  -14.00 | BD  -40.00 | CD  -26.00    (Iteration  4, r2 =  68236.6)
# AB  +32.00 | AC  +18.00 | AD   -9.00 | BC  -14.00 | BD  -41.00 | CD  -27.00    (Iteration  5, r2 =  68157.4)
# Rough time shifts done :
# AB  +32.00 | AC  +18.00 | AD   -9.00 | BC  -14.00 | BD  -41.00 | CD  -27.00
# Starting opt_rough on initial delays :
# AB  +32.00 | AC  +18.00 | AD   -9.00 | BC  -14.00 | BD  -41.00 | CD  -27.00
# Aiming at curves A, B, C, D.
# Starting ML optimization ...
# Done !
# First spline and ML opt done.
# AB  +33.00 | AC  +26.00 | AD  -15.00 | BC   -7.00 | BD  -48.00 | CD  -41.00    (Iteration  1, r2 =  64899.9)
# AB  +34.00 | AC  +28.00 | AD  -16.00 | BC   -6.00 | BD  -50.00 | CD  -44.00    (Iteration  2, r2 =  64750.3)
# AB  +35.00 | AC  +28.00 | AD  -16.00 | BC   -7.00 | BD  -51.00 | CD  -44.00    (Iteration  3, r2 =  64610.5)
# AB  +36.00 | AC  +29.00 | AD  -17.00 | BC   -7.00 | BD  -53.00 | CD  -46.00    (Iteration  4, r2 =  64487.1)
# AB  +36.00 | AC  +30.00 | AD  -17.00 | BC   -6.00 | BD  -53.00 | CD  -47.00    (Iteration  5, r2 =  64366.7)
# Rough time shifts done :
# AB  +36.00 | AC  +30.00 | AD  -17.00 | BC   -6.00 | BD  -53.00 | CD  -47.00
# Starting opt_fine on initial delays :
# AB  +36.00 | AC  +30.00 | AD  -17.00 | BC   -6.00 | BD  -53.00 | CD  -47.00
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +39.24 | AC  +35.18 | AD  -21.91 | BC   -4.06 | BD  -61.15 | CD  -57.08    (Iteration  1, r2 =  55875.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.44 | AC  +37.85 | AD  -26.26 | BC   -2.59 | BD  -66.71 | CD  -64.12    (Iteration  2, r2 =  54343.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.61 | AC  +38.58 | AD  -26.83 | BC   -2.03 | BD  -67.44 | CD  -65.41    (Iteration  3, r2 =  53618.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.53 | AC  +38.76 | AD  -26.89 | BC   -1.78 | BD  -67.43 | CD  -65.65    (Iteration  4, r2 =  53224.6)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.36 | AC  +38.67 | AD  -27.10 | BC   -1.69 | BD  -67.46 | CD  -65.77    (Iteration  5, r2 =  53036.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.31 | AC  +38.71 | AD  -27.33 | BC   -1.60 | BD  -67.63 | CD  -66.03    (Iteration  6, r2 =  52921.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.26 | AC  +38.70 | AD  -27.49 | BC   -1.55 | BD  -67.75 | CD  -66.19    (Iteration  7, r2 =  52853.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.17 | AC  +38.74 | AD  -27.55 | BC   -1.43 | BD  -67.72 | CD  -66.30    (Iteration  8, r2 =  52815.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.14 | AC  +38.72 | AD  -27.53 | BC   -1.42 | BD  -67.68 | CD  -66.25    (Iteration  9, r2 =  52794.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  +40.21 | AC  +38.70 | AD  -27.35 | BC   -1.51 | BD  -67.56 | CD  -66.05    (Iteration 10, r2 =  52770.7)
# Timeshift stabilization and releasing of splflat :
# AB  +40.17 | AC  +38.66 | AD  -27.35 | BC   -1.51 | BD  -67.52 | CD  -66.01    (Iteration  1, r2 =  52770.1)
# AB  +40.12 | AC  +38.66 | AD  -27.35 | BC   -1.46 | BD  -67.48 | CD  -66.01    (Iteration  2, r2 =  52769.8)
# AB  +40.12 | AC  +38.66 | AD  -27.35 | BC   -1.46 | BD  -67.48 | CD  -66.01    (Iteration  3, r2 =  52769.8)
# AB  +40.12 | AC  +38.66 | AD  -27.35 | BC   -1.46 | BD  -67.48 | CD  -66.01    (Iteration  4, r2 =  52769.8)
# AB  +40.12 | AC  +38.66 | AD  -27.35 | BC   -1.46 | BD  -67.48 | CD  -66.01    (Iteration  5, r2 =  52769.8)

# %%
print(lcs[1].longinfo())
# Out:
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# 	[Trial/B](27.975,-0.647,0)
# 192 points (total), 0 of which are masked
# 4 seasons (gap: >60), gap length : 164.0 +/- 33.8 days
# Sampling : median 4.0, mean 4.4, max 25.1, min 0.83 days
# Shifts : (27.97498,-0.64693,0.00) [days, mag, flux]
# Colour : blue
# Common properties :
#    All properties :
# Comments :
#    Imported from trialcurves.txt, columns (1, 4, 5)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# Now let's print out the measured time delays, computed from the current time shifts of each curve. Note that the `lcs` objects now contain shifts provided to them by the `spline` model.

# %%
basic_time_delays = pycs.gen.lc.getnicetimedelays(lcs, separator="\n", sorted=True)
print("Time Delays (no microlensing):")
print(basic_time_delays)
# Out:
# Time Delays (no microlensing):
# AB  +40.12
# AC  +38.66
# AD  -27.35
# BC   -1.46
# BD  -67.48
# CD  -66.01

# %%
for l in lcs:
    print(l.object)
# Out:
# A
# B
# C
# D

# %%
basic_time_delays = pycs.gen.lc.getnicetimedelays(lcs, separator="\n", sorted=False)
print("Time Delays (no microlensing):")
print(basic_time_delays)
# Out:
# Time Delays (no microlensing):
# AB  +40.12
# AC  +38.66
# AD  -27.35
# BC   -1.46
# BD  -67.48
# CD  -66.01

# %% [markdown]
# We can now redisplay our light curve plot, but with the spline model overlaid and the inferred shifts applied. Remember, it won't look very good, as the curves do not overlap without a microlensing model.

# %%
pycs.gen.lc.display(lcs, [spline], knotsize=0.01, figsize=(20, 7), jdrange=(53900, 55500))

# %% [markdown]
# ### 3.2 Including Microlensing
#
# Now let's factor in four independent polynomial curves to account for any microlensing in our light curves.

# %%
pycs.gen.polyml.addtolc(lcs[1], nparams=2, autoseasonsgap=600.0)
pycs.gen.polyml.addtolc(lcs[2], nparams=3, autoseasonsgap=600.0)
pycs.gen.polyml.addtolc(lcs[3], nparams=3, autoseasonsgap=600.0)

# %%
pycs.gen.lc.display(lcs)

# %% [markdown]
# Now, let's try the model optimization again. The result should be much better!

# %%
spline = spl(lcs)
# Out:
# Starting opt_rough on initial delays :
# AB  +40.12 | AC  +38.66 | AD  -27.35 | BC   -1.46 | BD  -67.48 | CD  -66.01
# Aiming at curves A.
# Starting ML optimization ...
# Working on the poly ML of [Trial/B](27.975,-0.647,0)|poly/2|
# Working on the poly ML of [Trial/C](26.511,-1.603,0)|poly/3|
# Working on the poly ML of [Trial/D](-39.502,-2.092,0)|poly/3|
# Done !
# First spline and ML opt done.
# AB  +16.12 | AC  +24.66 | AD  -44.35 | BC   +8.54 | BD  -60.48 | CD  -69.01    (Iteration  1, r2 =  30301.1)
# AB   -0.88 | AC   +3.66 | AD  -58.35 | BC   +4.54 | BD  -57.48 | CD  -62.01    (Iteration  2, r2 =  22636.6)
# AB   -8.88 | AC  -12.34 | AD  -64.35 | BC   -3.46 | BD  -55.48 | CD  -52.01    (Iteration  3, r2 =  19618.5)
# AB  -12.88 | AC  -21.34 | AD  -68.35 | BC   -8.46 | BD  -55.48 | CD  -47.01    (Iteration  4, r2 =  18598.7)
# AB  -14.88 | AC  -26.34 | AD  -69.35 | BC  -11.46 | BD  -54.48 | CD  -43.01    (Iteration  5, r2 =  18295.1)
# Rough time shifts done :
# AB  -14.88 | AC  -26.34 | AD  -69.35 | BC  -11.46 | BD  -54.48 | CD  -43.01
# Starting opt_rough on initial delays :
# AB  -14.88 | AC  -26.34 | AD  -69.35 | BC  -11.46 | BD  -54.48 | CD  -43.01
# Aiming at curves A.
# Starting ML optimization ...
# Working on the poly ML of [Trial/B](-14.025,-0.647,0)|poly/2|
# Working on the poly ML of [Trial/C](-25.489,-1.603,0)|poly/3|
# Working on the poly ML of [Trial/D](-68.502,-2.092,0)|poly/3|
# Done !
# First spline and ML opt done.
# AB  -15.88 | AC  -27.34 | AD  -73.35 | BC  -11.46 | BD  -57.48 | CD  -46.01    (Iteration  1, r2 =  14872.6)
# AB  -15.88 | AC  -27.34 | AD  -74.35 | BC  -11.46 | BD  -58.48 | CD  -47.01    (Iteration  2, r2 =  14869.3)
# AB  -15.88 | AC  -27.34 | AD  -75.35 | BC  -11.46 | BD  -59.48 | CD  -48.01    (Iteration  3, r2 =  14867.1)
# AB  -15.88 | AC  -27.34 | AD  -75.35 | BC  -11.46 | BD  -59.48 | CD  -48.01    (Iteration  4, r2 =  14867.0)
# AB  -15.88 | AC  -27.34 | AD  -75.35 | BC  -11.46 | BD  -59.48 | CD  -48.01    (Iteration  5, r2 =  14867.0)
# Rough time shifts done :
# AB  -15.88 | AC  -27.34 | AD  -75.35 | BC  -11.46 | BD  -59.48 | CD  -48.01
# Starting opt_fine on initial delays :
# AB  -15.88 | AC  -27.34 | AD  -75.35 | BC  -11.46 | BD  -59.48 | CD  -48.01
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -13.59 | AC  -24.84 | AD  -73.35 | BC  -11.25 | BD  -59.76 | CD  -48.52    (Iteration  1, r2 =  11370.6)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -12.98 | AC  -24.11 | AD  -72.48 | BC  -11.13 | BD  -59.50 | CD  -48.37    (Iteration  2, r2 =  11232.5)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -12.45 | AC  -23.78 | AD  -72.15 | BC  -11.33 | BD  -59.70 | CD  -48.37    (Iteration  3, r2 =  11124.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -12.09 | AC  -23.54 | AD  -72.03 | BC  -11.45 | BD  -59.94 | CD  -48.49    (Iteration  4, r2 =  11042.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -12.00 | AC  -23.53 | AD  -72.00 | BC  -11.53 | BD  -59.99 | CD  -48.47    (Iteration  5, r2 =  10980.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -11.82 | AC  -23.63 | AD  -71.96 | BC  -11.81 | BD  -60.13 | CD  -48.33    (Iteration  6, r2 =  10931.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -11.68 | AC  -23.60 | AD  -71.99 | BC  -11.92 | BD  -60.32 | CD  -48.39    (Iteration  7, r2 =  10893.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -11.51 | AC  -23.59 | AD  -71.96 | BC  -12.08 | BD  -60.45 | CD  -48.37    (Iteration  8, r2 =  10860.5)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -11.45 | AC  -23.73 | AD  -71.90 | BC  -12.28 | BD  -60.45 | CD  -48.17    (Iteration  9, r2 =  10831.5)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB  -11.37 | AC  -23.85 | AD  -71.93 | BC  -12.48 | BD  -60.57 | CD  -48.09    (Iteration 10, r2 =  10812.1)
# Timeshift stabilization and releasing of splflat :
# AB  -11.37 | AC  -23.89 | AD  -71.90 | BC  -12.52 | BD  -60.53 | CD  -48.01    (Iteration  1, r2 =  10811.0)
# AB  -11.37 | AC  -23.89 | AD  -71.96 | BC  -12.52 | BD  -60.58 | CD  -48.06    (Iteration  2, r2 =  10811.0)
# AB  -11.37 | AC  -23.89 | AD  -71.96 | BC  -12.52 | BD  -60.58 | CD  -48.06    (Iteration  3, r2 =  10811.0)
# AB  -11.37 | AC  -23.89 | AD  -71.96 | BC  -12.52 | BD  -60.58 | CD  -48.06    (Iteration  4, r2 =  10811.0)
# AB  -11.37 | AC  -23.89 | AD  -71.96 | BC  -12.52 | BD  -60.58 | CD  -48.06    (Iteration  5, r2 =  10811.0)

# %%
print(spline.datapoints)
# Out:
# <pycs.gen.spl.DataPoints instance at 0x112e5c518>

# %%
spline.display(showdatapoints=False,showerrorbars=False,showbounds=False)

# %%
pycs.gen.lc.display(lcs, [spline], knotsize=0.1, figsize=(20, 7), jdrange=(53900, 55500))

# %% [markdown]
# The new time delays should show the difference once microlensing is factored in. We'll compare our previous time delay output to this output.

# %%
polynomial_microlensing_time_delays = pycs.gen.lc.getnicetimedelays(lcs, separator="\n", sorted=True)
print("Time Delays (microlensing included, with polynomials):")
print(polynomial_microlensing_time_delays)

print("cf. Time Delays (no microlensing):")
print(basic_time_delays)
# Out:
# Time Delays (microlensing included, with polynomials):
# AB  -11.37
# AC  -23.89
# AD  -71.96
# BC  -12.52
# BD  -60.58
# CD  -48.06
# cf. Time Delays (no microlensing):
# AB  +40.12
# AC  +38.66
# AD  -27.35
# BC   -1.46
# BD  -67.48
# CD  -66.01

# %% [markdown]
# ### 3.3 Modeling Microlensing with Splines
#
# If we add spline models for the microlensing, they displace the polynomial model:

# %%
pycs.gen.splml.addtolc(lcs[0], knotstep=150)
pycs.gen.splml.addtolc(lcs[1], knotstep=150)
pycs.gen.splml.addtolc(lcs[2], knotstep=150)
pycs.gen.splml.addtolc(lcs[3], knotstep=150)
# Out:
# I replace an existing mircolensing.
# I replace an existing mircolensing.
# I replace an existing mircolensing.

# %% [markdown]
# Let's re-optimize and see what happens to the time delays:

# %%
spline = spl(lcs)
# Out:
# Starting opt_rough on initial delays :
# AB  -11.37 | AC  -23.89 | AD  -71.96 | BC  -12.52 | BD  -60.58 | CD  -48.06
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/A](-1.431,0.000,0)|~3/u/7~|
# Working on the spline ML of [Trial/B](-12.801,-0.647,0)|~3/u/7~|
# Working on the spline ML of [Trial/C](-25.321,-1.603,0)|~3/u/7~|
# Working on the spline ML of [Trial/D](-73.386,-2.092,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# AB  -12.37 | AC  -23.89 | AD  -76.96 | BC  -11.52 | BD  -64.58 | CD  -53.06    (Iteration  1, r2 =   9231.2)
# AB  -13.37 | AC  -23.89 | AD  -80.96 | BC  -10.52 | BD  -67.58 | CD  -57.06    (Iteration  2, r2 =   9162.1)
# AB  -13.37 | AC  -23.89 | AD  -82.96 | BC  -10.52 | BD  -69.58 | CD  -59.06    (Iteration  3, r2 =   9141.4)
# AB  -13.37 | AC  -23.89 | AD  -84.96 | BC  -10.52 | BD  -71.58 | CD  -61.06    (Iteration  4, r2 =   9128.7)
# AB  -13.37 | AC  -23.89 | AD  -85.96 | BC  -10.52 | BD  -72.58 | CD  -62.06    (Iteration  5, r2 =   9123.8)
# Rough time shifts done :
# AB  -13.37 | AC  -23.89 | AD  -85.96 | BC  -10.52 | BD  -72.58 | CD  -62.06
# Starting opt_rough on initial delays :
# AB  -13.37 | AC  -23.89 | AD  -85.96 | BC  -10.52 | BD  -72.58 | CD  -62.06
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/A](-1.431,0.000,0)|~3/u/7~|
# Working on the spline ML of [Trial/B](-14.801,-0.647,0)|~3/u/7~|
# Working on the spline ML of [Trial/C](-25.321,-1.603,0)|~3/u/7~|
# Working on the spline ML of [Trial/D](-87.386,-2.092,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# AB  -13.37 | AC  -23.89 | AD  -79.96 | BC  -10.52 | BD  -66.58 | CD  -56.06    (Iteration  1, r2 =   7140.2)
# AB  -12.37 | AC  -22.89 | AD  -77.96 | BC  -10.52 | BD  -65.58 | CD  -55.06    (Iteration  2, r2 =   7089.8)
# AB  -12.37 | AC  -22.89 | AD  -76.96 | BC  -10.52 | BD  -64.58 | CD  -54.06    (Iteration  3, r2 =   7080.0)
# AB  -12.37 | AC  -22.89 | AD  -76.96 | BC  -10.52 | BD  -64.58 | CD  -54.06    (Iteration  4, r2 =   7075.1)
# AB  -12.37 | AC  -22.89 | AD  -76.96 | BC  -10.52 | BD  -64.58 | CD  -54.06    (Iteration  5, r2 =   7071.5)
# Rough time shifts done :
# AB  -12.37 | AC  -22.89 | AD  -76.96 | BC  -10.52 | BD  -64.58 | CD  -54.06
# Starting opt_fine on initial delays :
# AB  -12.37 | AC  -22.89 | AD  -76.96 | BC  -10.52 | BD  -64.58 | CD  -54.06
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -7.34 | AC  -22.69 | AD  -70.51 | BC  -15.35 | BD  -63.17 | CD  -47.82    (Iteration  1, r2 =   2715.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -5.85 | AC  -21.53 | AD  -68.74 | BC  -15.69 | BD  -62.90 | CD  -47.21    (Iteration  2, r2 =   2354.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -5.37 | AC  -21.10 | AD  -68.40 | BC  -15.72 | BD  -63.03 | CD  -47.31    (Iteration  3, r2 =   2249.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -5.10 | AC  -20.89 | AD  -68.08 | BC  -15.80 | BD  -62.98 | CD  -47.19    (Iteration  4, r2 =   2218.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -4.99 | AC  -20.84 | AD  -68.04 | BC  -15.85 | BD  -63.05 | CD  -47.20    (Iteration  5, r2 =   2199.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -4.98 | AC  -20.85 | AD  -68.12 | BC  -15.88 | BD  -63.14 | CD  -47.26    (Iteration  6, r2 =   2193.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -4.96 | AC  -20.87 | AD  -68.19 | BC  -15.91 | BD  -63.23 | CD  -47.32    (Iteration  7, r2 =   2179.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -4.95 | AC  -20.84 | AD  -68.18 | BC  -15.89 | BD  -63.23 | CD  -47.34    (Iteration  8, r2 =   2177.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -4.97 | AC  -20.86 | AD  -68.20 | BC  -15.88 | BD  -63.23 | CD  -47.35    (Iteration  9, r2 =   2169.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AB   -4.96 | AC  -20.83 | AD  -68.19 | BC  -15.87 | BD  -63.23 | CD  -47.36    (Iteration 10, r2 =   2177.1)
# Timeshift stabilization and releasing of splflat :
# AB   -4.76 | AC  -20.68 | AD  -68.41 | BC  -15.92 | BD  -63.65 | CD  -47.73    (Iteration  1, r2 =   2115.6)
# AB   -4.76 | AC  -20.68 | AD  -68.47 | BC  -15.92 | BD  -63.71 | CD  -47.79    (Iteration  2, r2 =   2103.6)
# AB   -4.76 | AC  -20.68 | AD  -68.47 | BC  -15.92 | BD  -63.71 | CD  -47.79    (Iteration  3, r2 =   2096.0)
# AB   -4.76 | AC  -20.68 | AD  -68.47 | BC  -15.92 | BD  -63.71 | CD  -47.79    (Iteration  4, r2 =   2091.1)
# AB   -4.76 | AC  -20.68 | AD  -68.47 | BC  -15.92 | BD  -63.71 | CD  -47.79    (Iteration  5, r2 =   2087.8)

# %%
spline_microlensing_time_delays = pycs.gen.lc.getnicetimedelays(lcs, separator="\n", sorted=True)
print("Time Delays (microlensing included, with splines):")
print(spline_microlensing_time_delays)

print("cf. Time Delays (microlensing included, with polynomials):")
print(polynomial_microlensing_time_delays)
# Out:
# Time Delays (microlensing included, with splines):
# AB   -4.76
# AC  -20.68
# AD  -68.47
# BC  -15.92
# BD  -63.71
# CD  -47.79
# cf. Time Delays (microlensing included, with polynomials):
# AB  -11.37
# AC  -23.89
# AD  -71.96
# BC  -12.52
# BD  -60.58
# CD  -48.06

# %% [markdown]
# We see differences, but the results from the two types of microlensing model are much closer together than either of them are with the time delays from the "no microlensing" model.
#
# What do these spline microlensing models look like?

# %%
pycs.gen.lc.display(lcs, [spline], knotsize=0.01, figsize=(20, 7), jdrange=(53900, 55500))

# %% [markdown]
# Let's save this to a PDF figure:

# %%
pycs.gen.lc.display(lcs, [spline], knotsize=0.01, figsize=(20, 7), jdrange=(53900, 55500),filename="fig_modelfit.pdf")
# Out:
# Plot written to fig_modelfit.pdf

# %% [markdown]
# Now that we have a well-optimized model, lets save it and the shifted light curves to a pickle file that we can use later.

# %%
pycs.gen.util.writepickle((lcs, spline), "optspline.pkl")
# Out:
# Wrote optspline.pkl

# %% [markdown]
# ## 4. Estimating the Time Delay Uncertainties

# %% [markdown]
# Error estimation with `PyCS` is performed by re-sampling the data, re-optimizing the model, and accumulating statistics about the resulting time delays.
#
# To evaluate the intrinsic variance of the optimizer, we make `Ncopies` copies of the dataset, and re-optimize the model for each one. To probe the width of the likelihood function itself, we generate and use `Nmocks` synthetic datasets, with slightly different time delays. For the latter step, we need to read in an optimized model and its shifted light curves. In each case we'll need to collect together the many optimized light curves' time delays at the end, and compute some statistics.
#
# First, though, we need to clear out any previous simulations we did, because `PyCS` works on all files in a simulation folder, and we don't want to mix up any old files with new ones.

# %%
!\rm -rfv sims_copies sims_mocks
!\rm -rfv sims_copies_opt_spl sims_copies_opt_disp sims_copies_opt_regdiff
!\rm -rfv sims_mocks_opt_spl sims_mocks_opt_disp sims_mocks_opt_regdiff
# Out:
# sims_copies/1_1475037895.44316.pkl
# sims_copies/2_1475037895.45255.pkl
# sims_copies/3_1475037895.45869.pkl
# sims_copies/4_1475037895.46449.pkl
# sims_copies
# sims_mocks/1_1475037895.51862.pkl
# sims_mocks/2_1475037895.65321.pkl
# sims_mocks/3_1475037895.75946.pkl
# sims_mocks/4_1475037895.83591.pkl
# sims_mocks
# sims_copies_opt_spl/1_1475037895.44316_opt.pkl
# sims_copies_opt_spl/1_1475037895.44316_runresults.pkl
# sims_copies_opt_spl/2_1475037895.45255_opt.pkl
# sims_copies_opt_spl/2_1475037895.45255_runresults.pkl
# sims_copies_opt_spl/3_1475037895.45869_opt.pkl
# sims_copies_opt_spl/3_1475037895.45869_runresults.pkl
# sims_copies_opt_spl/4_1475037895.46449_opt.pkl
# sims_copies_opt_spl/4_1475037895.46449_runresults.pkl
# sims_copies_opt_spl
# sims_copies_opt_disp/1_1475037895.44316_runresults.pkl
# sims_copies_opt_disp/2_1475037895.45255_runresults.pkl
# sims_copies_opt_disp/3_1475037895.45869_runresults.pkl
# sims_copies_opt_disp/4_1475037895.46449_runresults.pkl
# sims_copies_opt_disp
# sims_copies_opt_regdiff/1_1475037895.44316_runresults.pkl
# sims_copies_opt_regdiff/2_1475037895.45255_runresults.pkl
# sims_copies_opt_regdiff/3_1475037895.45869_runresults.pkl
# sims_copies_opt_regdiff/4_1475037895.46449_runresults.pkl
# sims_copies_opt_regdiff
# sims_mocks_opt_spl/1_1475037895.51862_opt.pkl
# sims_mocks_opt_spl/1_1475037895.51862_runresults.pkl
# sims_mocks_opt_spl/2_1475037895.65321_opt.pkl
# sims_mocks_opt_spl/2_1475037895.65321_runresults.pkl
# sims_mocks_opt_spl/3_1475037895.75946_opt.pkl
# sims_mocks_opt_spl/3_1475037895.75946_runresults.pkl
# sims_mocks_opt_spl/4_1475037895.83591_opt.pkl
# sims_mocks_opt_spl/4_1475037895.83591_runresults.pkl
# sims_mocks_opt_spl
# sims_mocks_opt_disp/1_1475037895.51862_runresults.pkl
# sims_mocks_opt_disp/2_1475037895.65321_runresults.pkl
# sims_mocks_opt_disp/3_1475037895.75946_runresults.pkl
# sims_mocks_opt_disp/4_1475037895.83591_runresults.pkl
# sims_mocks_opt_disp
# sims_mocks_opt_regdiff/1_1475037895.51862_runresults.pkl
# sims_mocks_opt_regdiff/2_1475037895.65321_runresults.pkl
# sims_mocks_opt_regdiff/3_1475037895.75946_runresults.pkl
# sims_mocks_opt_regdiff/4_1475037895.83591_runresults.pkl
# sims_mocks_opt_regdiff

# %% [markdown]
# ### 4.1  Re-sampling the Light Curve Data
#
# First, the plain copies:

# %%
n, npkl = 1, 4
Ncopies = n*npkl
print("Making",Ncopies,"copies of the original dataset:")
pycs.sim.draw.multidraw(lcs, onlycopy=True, n=n, npkl=npkl, simset="copies")
# Out:
# Making 4 copies of the original dataset:
# Now thowing dice into sims_copies ...
# Input shifts :
# A    -5.70 | B   -10.46 | C   -26.38 | D   -74.17
# Input delays :
# AB   -4.76 | AC  -20.68 | AD  -68.47 | BC  -15.92 | BD  -63.71 | CD  -47.79
# Preparing 1 identical copies for pkl 1/4 ...
# Wrote sims_copies/1_1475093439.64908.pkl
# Preparing 1 identical copies for pkl 2/4 ...
# Wrote sims_copies/2_1475093439.65691.pkl
# Preparing 1 identical copies for pkl 3/4 ...
# Wrote sims_copies/3_1475093439.66198.pkl
# Preparing 1 identical copies for pkl 4/4 ...
# Wrote sims_copies/4_1475093439.66685.pkl

# %% [markdown]
# Now the synthetic light curves:

# %%
(modellcs, modelspline)  = pycs.gen.util.readpickle("optspline.pkl")
# Out:
# Read optspline.pkl

# %% [markdown]
# We want each synthetic light curve to have slightly different underlying microlensing signals as well as a slightly different set of time delays. This is achieved via a set of "tweak" functions, that implement some small scale extrinsic variability when we generate the synthetic curves. Note that the control parameters `beta`, `sigma`, and `fmin` have to be *asserted*, these values can be changed.

# %%
def Atweakml(lcs):
    return pycs.sim.twk.tweakml(lcs, beta=-1.5, sigma=0.25, fmin=1/500.0, fmax=None, psplot=False)

def Btweakml(lcs):
    return pycs.sim.twk.tweakml(lcs, beta=-1.0, sigma=0.9, fmin=1/500.0, fmax=None, psplot=False)

def Ctweakml(lcs):
    return pycs.sim.twk.tweakml(lcs, beta=-1.0, sigma=1.5, fmin=1/500.0, fmax=None, psplot=False)

def Dtweakml(lcs):
    return pycs.sim.twk.tweakml(lcs, beta=-0.0, sigma=4.5, fmin=1/500.0, fmax=None, psplot=False)

# %% [markdown]
# At this place, *only* if you know what you are doing, you can manually adjust the microlensing or the delays. If not, run this script. This will run `n` simulations for each element in the pickle file.

# %%
n, npkl = 1, 4
Nmocks = n*npkl
truetsr = 8.0
print("Making",Nmocks,"synthetic datasets, varying time delays by +/-",truetsr/2.0,"days")
pycs.sim.draw.saveresiduals(modellcs, modelspline)
pycs.sim.draw.multidraw(modellcs, modelspline, n=n, npkl=npkl, simset="mocks",
        truetsr=truetsr, tweakml=[Atweakml, Btweakml, Ctweakml, Dtweakml])
# Out:
# Making 4 synthetic datasets, varying time delays by +/- 4.0 days
# Now thowing dice into sims_mocks ...
# Input shifts :
# A    -5.70 | B   -10.46 | C   -26.38 | D   -74.17
# Input delays :
# AB   -4.76 | AC  -20.68 | AD  -68.47 | BC  -15.92 | BD  -63.71 | CD  -47.79
# Drawing 1 simulations for pkl 1/4 ...
# Wrote sims_mocks/1_1475093439.70907.pkl
# Drawing 1 simulations for pkl 2/4 ...
# Wrote sims_mocks/2_1475093439.78239.pkl
# Drawing 1 simulations for pkl 3/4 ...
# Wrote sims_mocks/3_1475093439.86694.pkl
# Drawing 1 simulations for pkl 4/4 ...
# Wrote sims_mocks/4_1475093439.92795.pkl

# %% [markdown]
# Note that we chose the name of our set of synthetic light curves "1Kset1" via the `simset` kwarg. "truetsr=8.0" means that the synthetic curves will get random true time shifts in a range of about 8.0 days around the time shifts of the model `lcs` objects.

# %% [markdown]
# ### 4.2 Re-running the Model Fits
#
# Now, we will run the free-knot spline technique using the plain copies we made earlier of the data. This will take a while: we're doing `Ncopies` separate model optimizations.

# %%
pycs.sim.run.multirun("copies", lcs, spl, optset="spl", tsrand=10.0, keepopt=True)
# Out:
# I have found 4 simulation pickles in sims_copies.
# I'll write my results into the directory sims_copies_opt_spl.
# Initial conditions :
# [Trial/A](-5.704,0.000,0)|~3/12l12b/7~|
# [Trial/B](-10.462,-0.647,0)|~3/12l12b/7~|
# [Trial/C](-26.383,-1.603,0)|~3/12l12b/7~|
# [Trial/D](-74.171,-2.092,0)|~3/12l12b/7~|
# --- Casino running on simset copies, optset spl ---
# Read sims_copies/1_1475093439.64908.pkl
# Working for sims_copies_opt_spl/1_1475093439.64908_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# BD  -45.25 | BC   -4.23 | BA  +12.52 | DC  +41.03 | DA  +57.77 | CA  +16.75
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/B](-19.380,-0.647,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/D](-64.633,-2.092,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/C](-23.606,-1.603,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/A](-6.859,0.000,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# BD  -54.25 | BC   -9.23 | BA   +9.52 | DC  +45.03 | DA  +63.77 | CA  +18.75    (Iteration  1, r2 =   7758.4)
# BD  -60.25 | BC  -11.23 | BA   +8.52 | DC  +49.03 | DA  +68.77 | CA  +19.75    (Iteration  2, r2 =   7651.2)
# BD  -64.25 | BC  -12.23 | BA   +7.52 | DC  +52.03 | DA  +71.77 | CA  +19.75    (Iteration  3, r2 =   7606.5)
# BD  -66.25 | BC  -12.23 | BA   +7.52 | DC  +54.03 | DA  +73.77 | CA  +19.75    (Iteration  4, r2 =   7597.1)
# BD  -67.25 | BC  -12.23 | BA   +7.52 | DC  +55.03 | DA  +74.77 | CA  +19.75    (Iteration  5, r2 =   7596.1)
# Rough time shifts done :
# BD  -67.25 | BC  -12.23 | BA   +7.52 | DC  +55.03 | DA  +74.77 | CA  +19.75
# Starting opt_rough on initial delays :
# BD  -67.25 | BC  -12.23 | BA   +7.52 | DC  +55.03 | DA  +74.77 | CA  +19.75
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/B](-15.380,-0.647,0)|~3/u/7~|
# Working on the spline ML of [Trial/D](-82.633,-2.092,0)|~3/u/7~|
# Working on the spline ML of [Trial/C](-27.606,-1.603,0)|~3/u/7~|
# Working on the spline ML of [Trial/A](-7.859,0.000,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# BD  -66.25 | BC  -11.23 | BA  +10.52 | DC  +55.03 | DA  +76.77 | CA  +21.75    (Iteration  1, r2 =   7440.8)
# BD  -66.25 | BC  -11.23 | BA  +10.52 | DC  +55.03 | DA  +76.77 | CA  +21.75    (Iteration  2, r2 =   7428.4)
# BD  -66.25 | BC  -11.23 | BA  +10.52 | DC  +55.03 | DA  +76.77 | CA  +21.75    (Iteration  3, r2 =   7421.0)
# BD  -66.25 | BC  -11.23 | BA  +10.52 | DC  +55.03 | DA  +76.77 | CA  +21.75    (Iteration  4, r2 =   7415.5)
# BD  -66.25 | BC  -11.23 | BA  +10.52 | DC  +55.03 | DA  +76.77 | CA  +21.75    (Iteration  5, r2 =   7410.8)
# Rough time shifts done :
# BD  -66.25 | BC  -11.23 | BA  +10.52 | DC  +55.03 | DA  +76.77 | CA  +21.75
# Starting opt_fine on initial delays :
# BD  -66.25 | BC  -11.23 | BA  +10.52 | DC  +55.03 | DA  +76.77 | CA  +21.75
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -63.40 | BC  -15.21 | BA   +7.82 | DC  +48.19 | DA  +71.22 | CA  +23.03    (Iteration  1, r2 =   3451.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -62.67 | BC  -15.71 | BA   +7.22 | DC  +46.97 | DA  +69.89 | CA  +22.92    (Iteration  2, r2 =   3268.4)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -62.76 | BC  -15.75 | BA   +7.16 | DC  +47.01 | DA  +69.92 | CA  +22.91    (Iteration  3, r2 =   3178.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -62.84 | BC  -15.85 | BA   +7.08 | DC  +46.99 | DA  +69.92 | CA  +22.93    (Iteration  4, r2 =   3137.4)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -63.04 | BC  -15.85 | BA   +7.00 | DC  +47.19 | DA  +70.04 | CA  +22.85    (Iteration  5, r2 =   3094.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -63.00 | BC  -15.95 | BA   +7.04 | DC  +47.05 | DA  +70.04 | CA  +23.00    (Iteration  6, r2 =   3063.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -63.17 | BC  -15.86 | BA   +7.08 | DC  +47.31 | DA  +70.25 | CA  +22.94    (Iteration  7, r2 =   3014.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -63.23 | BC  -15.95 | BA   +6.97 | DC  +47.27 | DA  +70.20 | CA  +22.93    (Iteration  8, r2 =   2982.4)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -63.32 | BC  -16.00 | BA   +6.97 | DC  +47.31 | DA  +70.28 | CA  +22.97    (Iteration  9, r2 =   2985.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -63.35 | BC  -15.90 | BA   +7.01 | DC  +47.45 | DA  +70.37 | CA  +22.92    (Iteration 10, r2 =   2997.7)
# Timeshift stabilization and releasing of splflat :
# BD  -64.56 | BC  -16.41 | BA   +5.35 | DC  +48.15 | DA  +69.91 | CA  +21.76    (Iteration  1, r2 =   2335.3)
# BD  -64.59 | BC  -16.41 | BA   +5.17 | DC  +48.19 | DA  +69.76 | CA  +21.58    (Iteration  2, r2 =   2321.3)
# BD  -64.59 | BC  -16.31 | BA   +5.17 | DC  +48.28 | DA  +69.76 | CA  +21.48    (Iteration  3, r2 =   2315.2)
# BD  -64.59 | BC  -16.31 | BA   +5.17 | DC  +48.28 | DA  +69.76 | CA  +21.48    (Iteration  4, r2 =   2311.3)
# BD  -64.59 | BC  -16.31 | BA   +5.17 | DC  +48.28 | DA  +69.76 | CA  +21.48    (Iteration  5, r2 =   2308.6)
# Shifted 1 simulations, using 1 CPU, time : 21
# Wrote sims_copies_opt_spl/1_1475093439.64908_opt.pkl
# Wrote sims_copies_opt_spl/1_1475093439.64908_runresults.pkl
# --- Casino running on simset copies, optset spl ---
# Read sims_copies/2_1475093439.65691.pkl
# Working for sims_copies_opt_spl/2_1475093439.65691_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# AD  -58.70 | AC  -13.30 | AB   -4.16 | DC  +45.39 | DB  +54.54 | CB   +9.14
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/A](-6.240,0.000,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/D](-64.937,-2.092,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/C](-19.545,-1.603,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/B](-10.400,-0.647,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# AD  -65.70 | AC  -16.30 | AB   -5.16 | DC  +49.39 | DB  +60.54 | CB  +11.14    (Iteration  1, r2 =   7716.2)
# AD  -69.70 | AC  -17.30 | AB   -5.16 | DC  +52.39 | DB  +64.54 | CB  +12.14    (Iteration  2, r2 =   7670.5)
# AD  -72.70 | AC  -18.30 | AB   -5.16 | DC  +54.39 | DB  +67.54 | CB  +13.14    (Iteration  3, r2 =   7653.2)
# AD  -73.70 | AC  -18.30 | AB   -5.16 | DC  +55.39 | DB  +68.54 | CB  +13.14    (Iteration  4, r2 =   7652.1)
# AD  -74.70 | AC  -18.30 | AB   -5.16 | DC  +56.39 | DB  +69.54 | CB  +13.14    (Iteration  5, r2 =   7652.6)
# Rough time shifts done :
# AD  -74.70 | AC  -18.30 | AB   -5.16 | DC  +56.39 | DB  +69.54 | CB  +13.14
# Starting opt_rough on initial delays :
# AD  -74.70 | AC  -18.30 | AB   -5.16 | DC  +56.39 | DB  +69.54 | CB  +13.14
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/A](-6.240,0.000,0)|~3/u/7~|
# Working on the spline ML of [Trial/D](-80.937,-2.092,0)|~3/u/7~|
# Working on the spline ML of [Trial/C](-24.545,-1.603,0)|~3/u/7~|
# Working on the spline ML of [Trial/B](-11.400,-0.647,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# AD  -75.70 | AC  -20.30 | AB   -9.16 | DC  +55.39 | DB  +66.54 | CB  +11.14    (Iteration  1, r2 =   7298.5)
# AD  -75.70 | AC  -21.30 | AB  -10.16 | DC  +54.39 | DB  +65.54 | CB  +11.14    (Iteration  2, r2 =   7250.5)
# AD  -75.70 | AC  -21.30 | AB  -11.16 | DC  +54.39 | DB  +64.54 | CB  +10.14    (Iteration  3, r2 =   7237.6)
# AD  -75.70 | AC  -22.30 | AB  -11.16 | DC  +53.39 | DB  +64.54 | CB  +11.14    (Iteration  4, r2 =   7231.7)
# AD  -75.70 | AC  -22.30 | AB  -11.16 | DC  +53.39 | DB  +64.54 | CB  +11.14    (Iteration  5, r2 =   7228.8)
# Rough time shifts done :
# AD  -75.70 | AC  -22.30 | AB  -11.16 | DC  +53.39 | DB  +64.54 | CB  +11.14
# Starting opt_fine on initial delays :
# AD  -75.70 | AC  -22.30 | AB  -11.16 | DC  +53.39 | DB  +64.54 | CB  +11.14
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -69.94 | AC  -22.55 | AB   -6.99 | DC  +47.39 | DB  +62.95 | CB  +15.56    (Iteration  1, r2 =   2604.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -68.77 | AC  -21.53 | AB   -5.67 | DC  +47.24 | DB  +63.10 | CB  +15.87    (Iteration  2, r2 =   2347.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -68.48 | AC  -21.28 | AB   -5.33 | DC  +47.21 | DB  +63.16 | CB  +15.95    (Iteration  3, r2 =   2259.6)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -68.18 | AC  -21.15 | AB   -5.15 | DC  +47.02 | DB  +63.02 | CB  +16.00    (Iteration  4, r2 =   2239.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -67.90 | AC  -20.95 | AB   -5.04 | DC  +46.95 | DB  +62.85 | CB  +15.91    (Iteration  5, r2 =   2226.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -67.95 | AC  -20.96 | AB   -5.05 | DC  +46.99 | DB  +62.91 | CB  +15.91    (Iteration  6, r2 =   2224.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -67.84 | AC  -20.83 | AB   -4.94 | DC  +47.01 | DB  +62.91 | CB  +15.90    (Iteration  7, r2 =   2215.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -67.85 | AC  -20.78 | AB   -4.97 | DC  +47.07 | DB  +62.88 | CB  +15.81    (Iteration  8, r2 =   2211.6)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -67.79 | AC  -20.81 | AB   -5.00 | DC  +46.98 | DB  +62.79 | CB  +15.82    (Iteration  9, r2 =   2215.6)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AD  -67.77 | AC  -20.72 | AB   -4.91 | DC  +47.05 | DB  +62.85 | CB  +15.80    (Iteration 10, r2 =   2212.1)
# Timeshift stabilization and releasing of splflat :
# AD  -67.71 | AC  -20.72 | AB   -4.83 | DC  +46.99 | DB  +62.88 | CB  +15.89    (Iteration  1, r2 =   2161.6)
# AD  -67.83 | AC  -20.72 | AB   -4.83 | DC  +47.11 | DB  +63.00 | CB  +15.89    (Iteration  2, r2 =   2150.8)
# AD  -67.89 | AC  -20.72 | AB   -4.83 | DC  +47.17 | DB  +63.06 | CB  +15.89    (Iteration  3, r2 =   2143.5)
# AD  -68.01 | AC  -20.72 | AB   -4.83 | DC  +47.29 | DB  +63.18 | CB  +15.89    (Iteration  4, r2 =   2138.4)
# AD  -68.07 | AC  -20.81 | AB   -4.83 | DC  +47.26 | DB  +63.24 | CB  +15.98    (Iteration  5, r2 =   2134.7)
# Shifted 1 simulations, using 1 CPU, time : 20
# Wrote sims_copies_opt_spl/2_1475093439.65691_opt.pkl
# Wrote sims_copies_opt_spl/2_1475093439.65691_runresults.pkl
# --- Casino running on simset copies, optset spl ---
# Read sims_copies/3_1475093439.66198.pkl
# Working for sims_copies_opt_spl/3_1475093439.66198_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# AC  -16.85 | AD  -73.91 | AB  -10.59 | CD  -57.06 | CB   +6.26 | DB  +63.32
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/A](-8.076,0.000,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/C](-24.921,-1.603,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/D](-81.982,-2.092,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/B](-18.661,-0.647,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# AC  -18.85 | AD  -73.91 | AB   -8.59 | CD  -55.06 | CB  +10.26 | DB  +65.32    (Iteration  1, r2 =   7876.5)
# AC  -18.85 | AD  -73.91 | AB   -7.59 | CD  -55.06 | CB  +11.26 | DB  +66.32    (Iteration  2, r2 =   7780.9)
# AC  -19.85 | AD  -74.91 | AB   -7.59 | CD  -55.06 | CB  +12.26 | DB  +67.32    (Iteration  3, r2 =   7770.9)
# AC  -18.85 | AD  -74.91 | AB   -6.59 | CD  -56.06 | CB  +12.26 | DB  +68.32    (Iteration  4, r2 =   7707.1)
# AC  -19.85 | AD  -75.91 | AB   -6.59 | CD  -56.06 | CB  +13.26 | DB  +69.32    (Iteration  5, r2 =   7704.8)
# Rough time shifts done :
# AC  -19.85 | AD  -75.91 | AB   -6.59 | CD  -56.06 | CB  +13.26 | DB  +69.32
# Starting opt_rough on initial delays :
# AC  -19.85 | AD  -75.91 | AB   -6.59 | CD  -56.06 | CB  +13.26 | DB  +69.32
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/A](-11.076,0.000,0)|~3/u/7~|
# Working on the spline ML of [Trial/C](-30.921,-1.603,0)|~3/u/7~|
# Working on the spline ML of [Trial/D](-86.982,-2.092,0)|~3/u/7~|
# Working on the spline ML of [Trial/B](-17.661,-0.647,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# AC  -21.85 | AD  -75.91 | AB   -9.59 | CD  -54.06 | CB  +12.26 | DB  +66.32    (Iteration  1, r2 =   7246.5)
# AC  -21.85 | AD  -75.91 | AB  -10.59 | CD  -54.06 | CB  +11.26 | DB  +65.32    (Iteration  2, r2 =   7212.2)
# AC  -21.85 | AD  -75.91 | AB  -10.59 | CD  -54.06 | CB  +11.26 | DB  +65.32    (Iteration  3, r2 =   7206.5)
# AC  -21.85 | AD  -75.91 | AB  -10.59 | CD  -54.06 | CB  +11.26 | DB  +65.32    (Iteration  4, r2 =   7202.6)
# AC  -21.85 | AD  -75.91 | AB  -10.59 | CD  -54.06 | CB  +11.26 | DB  +65.32    (Iteration  5, r2 =   7199.4)
# Rough time shifts done :
# AC  -21.85 | AD  -75.91 | AB  -10.59 | CD  -54.06 | CB  +11.26 | DB  +65.32
# Starting opt_fine on initial delays :
# AC  -21.85 | AD  -75.91 | AB  -10.59 | CD  -54.06 | CB  +11.26 | DB  +65.32
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -22.58 | AD  -69.92 | AB   -6.86 | CD  -47.34 | CB  +15.72 | DB  +63.06    (Iteration  1, r2 =   2588.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -21.57 | AD  -68.74 | AB   -5.65 | CD  -47.17 | CB  +15.92 | DB  +63.09    (Iteration  2, r2 =   2333.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -21.19 | AD  -68.36 | AB   -5.32 | CD  -47.17 | CB  +15.87 | DB  +63.04    (Iteration  3, r2 =   2252.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -21.12 | AD  -68.14 | AB   -5.12 | CD  -47.02 | CB  +16.00 | DB  +63.02    (Iteration  4, r2 =   2236.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -20.85 | AD  -67.86 | AB   -5.01 | CD  -47.01 | CB  +15.84 | DB  +62.85    (Iteration  5, r2 =   2224.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -20.84 | AD  -67.85 | AB   -5.04 | CD  -47.01 | CB  +15.79 | DB  +62.80    (Iteration  6, r2 =   2226.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -20.75 | AD  -67.94 | AB   -5.03 | CD  -47.19 | CB  +15.72 | DB  +62.91    (Iteration  7, r2 =   2207.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -20.74 | AD  -67.92 | AB   -5.01 | CD  -47.18 | CB  +15.73 | DB  +62.91    (Iteration  8, r2 =   2207.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -20.80 | AD  -68.01 | AB   -5.08 | CD  -47.21 | CB  +15.72 | DB  +62.93    (Iteration  9, r2 =   2200.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# AC  -20.87 | AD  -67.97 | AB   -5.01 | CD  -47.10 | CB  +15.85 | DB  +62.95    (Iteration 10, r2 =   2198.0)
# Timeshift stabilization and releasing of splflat :
# AC  -20.65 | AD  -67.97 | AB   -4.89 | CD  -47.32 | CB  +15.75 | DB  +63.07    (Iteration  1, r2 =   2145.9)
# AC  -20.64 | AD  -68.07 | AB   -4.94 | CD  -47.44 | CB  +15.70 | DB  +63.14    (Iteration  2, r2 =   2131.0)
# AC  -20.68 | AD  -68.18 | AB   -4.92 | CD  -47.50 | CB  +15.76 | DB  +63.26    (Iteration  3, r2 =   2121.4)
# AC  -20.63 | AD  -68.25 | AB   -4.86 | CD  -47.62 | CB  +15.76 | DB  +63.38    (Iteration  4, r2 =   2115.3)
# AC  -20.67 | AD  -68.35 | AB   -4.91 | CD  -47.68 | CB  +15.76 | DB  +63.45    (Iteration  5, r2 =   2110.8)
# Shifted 1 simulations, using 1 CPU, time : 23
# Wrote sims_copies_opt_spl/3_1475093439.66198_opt.pkl
# Wrote sims_copies_opt_spl/3_1475093439.66198_runresults.pkl
# --- Casino running on simset copies, optset spl ---
# Read sims_copies/4_1475093439.66685.pkl
# Working for sims_copies_opt_spl/4_1475093439.66685_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# BA   -0.89 | BC  -29.14 | BD  -70.65 | AC  -28.25 | AD  -69.76 | CD  -41.51
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/B](-5.404,-0.647,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/A](-6.295,0.000,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/C](-34.548,-1.603,0)|~3/12l12b/7~|
# Working on the spline ML of [Trial/D](-76.053,-2.092,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# BA   +1.11 | BC  -22.14 | BD  -70.65 | AC  -23.25 | AD  -71.76 | CD  -48.51    (Iteration  1, r2 =   8117.9)
# BA   +2.11 | BC  -19.14 | BD  -71.65 | AC  -21.25 | AD  -73.76 | CD  -52.51    (Iteration  2, r2 =   7995.2)
# BA   +3.11 | BC  -17.14 | BD  -71.65 | AC  -20.25 | AD  -74.76 | CD  -54.51    (Iteration  3, r2 =   7922.8)
# BA   +4.11 | BC  -15.14 | BD  -71.65 | AC  -19.25 | AD  -75.76 | CD  -56.51    (Iteration  4, r2 =   7874.4)
# BA   +4.11 | BC  -15.14 | BD  -71.65 | AC  -19.25 | AD  -75.76 | CD  -56.51    (Iteration  5, r2 =   7863.7)
# Rough time shifts done :
# BA   +4.11 | BC  -15.14 | BD  -71.65 | AC  -19.25 | AD  -75.76 | CD  -56.51
# Starting opt_rough on initial delays :
# BA   +4.11 | BC  -15.14 | BD  -71.65 | AC  -19.25 | AD  -75.76 | CD  -56.51
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trial/B](-10.404,-0.647,0)|~3/u/7~|
# Working on the spline ML of [Trial/A](-6.295,0.000,0)|~3/u/7~|
# Working on the spline ML of [Trial/C](-25.548,-1.603,0)|~3/u/7~|
# Working on the spline ML of [Trial/D](-82.053,-2.092,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# BA   +9.11 | BC  -12.14 | BD  -67.65 | AC  -21.25 | AD  -76.76 | CD  -55.51    (Iteration  1, r2 =   7457.0)
# BA  +10.11 | BC  -11.14 | BD  -66.65 | AC  -21.25 | AD  -76.76 | CD  -55.51    (Iteration  2, r2 =   7421.4)
# BA  +10.11 | BC  -12.14 | BD  -66.65 | AC  -22.25 | AD  -76.76 | CD  -54.51    (Iteration  3, r2 =   7411.2)
# BA  +11.11 | BC  -11.14 | BD  -65.65 | AC  -22.25 | AD  -76.76 | CD  -54.51    (Iteration  4, r2 =   7403.8)
# BA  +11.11 | BC  -11.14 | BD  -65.65 | AC  -22.25 | AD  -76.76 | CD  -54.51    (Iteration  5, r2 =   7399.0)
# Rough time shifts done :
# BA  +11.11 | BC  -11.14 | BD  -65.65 | AC  -22.25 | AD  -76.76 | CD  -54.51
# Starting opt_fine on initial delays :
# BA  +11.11 | BC  -11.14 | BD  -65.65 | AC  -22.25 | AD  -76.76 | CD  -54.51
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.74 | BC  -14.90 | BD  -63.31 | AC  -22.63 | AD  -71.04 | CD  -48.41    (Iteration  1, r2 =   3470.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.12 | BC  -15.28 | BD  -63.01 | AC  -22.39 | AD  -70.13 | CD  -47.74    (Iteration  2, r2 =   3315.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.03 | BC  -15.38 | BD  -63.15 | AC  -22.41 | AD  -70.18 | CD  -47.77    (Iteration  3, r2 =   3254.6)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.07 | BC  -15.59 | BD  -63.26 | AC  -22.66 | AD  -70.34 | CD  -47.68    (Iteration  4, r2 =   3213.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.12 | BC  -15.61 | BD  -63.38 | AC  -22.72 | AD  -70.49 | CD  -47.77    (Iteration  5, r2 =   3206.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.03 | BC  -15.81 | BD  -63.76 | AC  -22.84 | AD  -70.79 | CD  -47.95    (Iteration  6, r2 =   3195.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.05 | BC  -15.81 | BD  -63.84 | AC  -22.86 | AD  -70.89 | CD  -48.03    (Iteration  7, r2 =   3201.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.05 | BC  -15.81 | BD  -63.98 | AC  -22.86 | AD  -71.03 | CD  -48.17    (Iteration  8, r2 =   3203.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.14 | BC  -15.77 | BD  -64.01 | AC  -22.91 | AD  -71.16 | CD  -48.25    (Iteration  9, r2 =   3199.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BA   +7.14 | BC  -15.77 | BD  -64.01 | AC  -22.91 | AD  -71.16 | CD  -48.25    (Iteration 10, r2 =   3204.0)
# Timeshift stabilization and releasing of splflat :
# BA   +5.45 | BC  -16.45 | BD  -64.83 | AC  -21.90 | AD  -70.28 | CD  -48.38    (Iteration  1, r2 =   2378.0)
# BA   +5.27 | BC  -16.35 | BD  -64.85 | AC  -21.62 | AD  -70.13 | CD  -48.51    (Iteration  2, r2 =   2366.2)
# BA   +5.31 | BC  -16.27 | BD  -64.71 | AC  -21.57 | AD  -70.02 | CD  -48.45    (Iteration  3, r2 =   2361.2)
# BA   +5.26 | BC  -16.27 | BD  -64.71 | AC  -21.53 | AD  -69.97 | CD  -48.45    (Iteration  4, r2 =   2357.7)
# BA   +5.23 | BC  -16.36 | BD  -64.71 | AC  -21.59 | AD  -69.95 | CD  -48.35    (Iteration  5, r2 =   2355.0)
# Shifted 1 simulations, using 1 CPU, time : 21
# Wrote sims_copies_opt_spl/4_1475093439.66685_opt.pkl
# Wrote sims_copies_opt_spl/4_1475093439.66685_runresults.pkl

# %% [markdown]
# Now, we will run the free-knot spline technique on each of the `Nmocks` synthetic light curve datasets we made earlier - again, this will take a while. Note the `keepopt=True` kwarg: this will make it easier to read the residuals from the synthetic curves with the residuals from the observed data. You can change the name "optset" to anything, though it should best reflect the name of the full method, including the settings of the microlensing.

# %%
tsrand = 1.0
pycs.sim.run.multirun("mocks", lcs, spl, optset="spl", tsrand=tsrand, keepopt=True)
# Out:
# I have found 4 simulation pickles in sims_mocks.
# I'll write my results into the directory sims_mocks_opt_spl.
# Initial conditions :
# [Trial/A](-5.704,0.000,0)|~3/12l12b/7~|
# [Trial/B](-10.462,-0.647,0)|~3/12l12b/7~|
# [Trial/C](-26.383,-1.603,0)|~3/12l12b/7~|
# [Trial/D](-74.171,-2.092,0)|~3/12l12b/7~|
# --- Casino running on simset mocks, optset spl ---
# Read sims_mocks/1_1475093439.70907.pkl
# Working for sims_mocks_opt_spl/1_1475093439.70907_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# DC  +46.56 | DB  +63.35 | DA  +68.02 | CB  +16.80 | CA  +21.46 | BA   +4.67
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/D](-73.427,-2.092,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/C](-26.870,-1.686,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/B](-10.074,-0.687,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/A](-5.406,-0.060,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# DC  +60.56 | DB  +69.35 | DA  +81.02 | CB   +8.80 | CA  +20.46 | BA  +11.67    (Iteration  1, r2 =  10044.4)
# DC  +66.56 | DB  +71.35 | DA  +87.02 | CB   +4.80 | CA  +20.46 | BA  +15.67    (Iteration  2, r2 =   9530.6)
# DC  +68.56 | DB  +71.35 | DA  +89.02 | CB   +2.80 | CA  +20.46 | BA  +17.67    (Iteration  3, r2 =   9345.1)
# DC  +69.56 | DB  +71.35 | DA  +90.02 | CB   +1.80 | CA  +20.46 | BA  +18.67    (Iteration  4, r2 =   9263.2)
# DC  +70.56 | DB  +71.35 | DA  +91.02 | CB   +0.80 | CA  +20.46 | BA  +19.67    (Iteration  5, r2 =   9200.3)
# Rough time shifts done :
# DC  +70.56 | DB  +71.35 | DA  +91.02 | CB   +0.80 | CA  +20.46 | BA  +19.67
# Starting opt_rough on initial delays :
# DC  +70.56 | DB  +71.35 | DA  +91.02 | CB   +0.80 | CA  +20.46 | BA  +19.67
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/D](-94.427,-2.092,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/C](-23.870,-1.686,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/B](-23.074,-0.687,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/A](-3.406,-0.060,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# DC  +63.56 | DB  +65.35 | DA  +88.02 | CB   +1.80 | CA  +24.46 | BA  +22.67    (Iteration  1, r2 =   8544.7)
# DC  +61.56 | DB  +63.35 | DA  +87.02 | CB   +1.80 | CA  +25.46 | BA  +23.67    (Iteration  2, r2 =   8481.2)
# DC  +61.56 | DB  +62.35 | DA  +87.02 | CB   +0.80 | CA  +25.46 | BA  +24.67    (Iteration  3, r2 =   8450.6)
# DC  +61.56 | DB  +62.35 | DA  +87.02 | CB   +0.80 | CA  +25.46 | BA  +24.67    (Iteration  4, r2 =   8428.8)
# DC  +61.56 | DB  +62.35 | DA  +87.02 | CB   +0.80 | CA  +25.46 | BA  +24.67    (Iteration  5, r2 =   8408.4)
# Rough time shifts done :
# DC  +61.56 | DB  +62.35 | DA  +87.02 | CB   +0.80 | CA  +25.46 | BA  +24.67
# Starting opt_fine on initial delays :
# DC  +61.56 | DB  +62.35 | DA  +87.02 | CB   +0.80 | CA  +25.46 | BA  +24.67
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +58.31 | DB  +62.77 | DA  +83.95 | CB   +4.46 | CA  +25.64 | BA  +21.18    (Iteration  1, r2 =   3133.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +58.24 | DB  +62.90 | DA  +83.35 | CB   +4.66 | CA  +25.10 | BA  +20.45    (Iteration  2, r2 =   3049.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +58.33 | DB  +63.05 | DA  +83.36 | CB   +4.72 | CA  +25.03 | BA  +20.31    (Iteration  3, r2 =   3015.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +58.37 | DB  +63.24 | DA  +83.30 | CB   +4.86 | CA  +24.92 | BA  +20.06    (Iteration  4, r2 =   3020.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +58.57 | DB  +63.24 | DA  +83.21 | CB   +4.66 | CA  +24.63 | BA  +19.97    (Iteration  5, r2 =   3017.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +58.57 | DB  +63.24 | DA  +83.08 | CB   +4.66 | CA  +24.51 | BA  +19.85    (Iteration  6, r2 =   3069.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +57.97 | DB  +63.16 | DA  +83.02 | CB   +5.19 | CA  +25.05 | BA  +19.86    (Iteration  7, r2 =   2996.6)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +57.68 | DB  +63.16 | DA  +82.96 | CB   +5.48 | CA  +25.28 | BA  +19.80    (Iteration  8, r2 =   3062.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +57.78 | DB  +63.16 | DA  +82.89 | CB   +5.37 | CA  +25.11 | BA  +19.73    (Iteration  9, r2 =   2997.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +57.78 | DB  +63.24 | DA  +82.83 | CB   +5.45 | CA  +25.04 | BA  +19.59    (Iteration 10, r2 =   2711.1)
# Timeshift stabilization and releasing of splflat :
# DC  +58.27 | DB  +63.91 | DA  +82.84 | CB   +5.63 | CA  +24.56 | BA  +18.93    (Iteration  1, r2 =   2262.5)
# DC  +58.36 | DB  +64.26 | DA  +83.08 | CB   +5.90 | CA  +24.72 | BA  +18.82    (Iteration  2, r2 =   2211.2)
# DC  +58.41 | DB  +64.36 | DA  +83.22 | CB   +5.95 | CA  +24.81 | BA  +18.85    (Iteration  3, r2 =   2196.0)
# DC  +58.38 | DB  +64.43 | DA  +83.29 | CB   +6.05 | CA  +24.90 | BA  +18.85    (Iteration  4, r2 =   2189.3)
# DC  +58.38 | DB  +64.43 | DA  +83.25 | CB   +6.05 | CA  +24.87 | BA  +18.82    (Iteration  5, r2 =   2185.4)
# Shifted 1 simulations, using 1 CPU, time : 26
# Wrote sims_mocks_opt_spl/1_1475093439.70907_opt.pkl
# Wrote sims_mocks_opt_spl/1_1475093439.70907_runresults.pkl
# --- Casino running on simset mocks, optset spl ---
# Read sims_mocks/2_1475093439.78239.pkl
# Working for sims_mocks_opt_spl/2_1475093439.78239_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# CA  +20.81 | CB  +15.71 | CD  -48.39 | AB   -5.10 | AD  -69.20 | BD  -64.10
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/C](-25.541,-1.603,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/A](-4.731,0.026,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/B](-9.831,-0.646,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/D](-73.928,-2.127,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# CA  +21.81 | CB  +15.71 | CD  -44.39 | AB   -6.10 | AD  -66.20 | BD  -60.10    (Iteration  1, r2 =  11669.3)
# CA  +21.81 | CB  +15.71 | CD  -44.39 | AB   -6.10 | AD  -66.20 | BD  -60.10    (Iteration  2, r2 =  11636.7)
# CA  +21.81 | CB  +15.71 | CD  -44.39 | AB   -6.10 | AD  -66.20 | BD  -60.10    (Iteration  3, r2 =  11611.6)
# CA  +21.81 | CB  +15.71 | CD  -44.39 | AB   -6.10 | AD  -66.20 | BD  -60.10    (Iteration  4, r2 =  11592.9)
# CA  +21.81 | CB  +15.71 | CD  -44.39 | AB   -6.10 | AD  -66.20 | BD  -60.10    (Iteration  5, r2 =  11579.0)
# Rough time shifts done :
# CA  +21.81 | CB  +15.71 | CD  -44.39 | AB   -6.10 | AD  -66.20 | BD  -60.10
# Starting opt_rough on initial delays :
# CA  +21.81 | CB  +15.71 | CD  -44.39 | AB   -6.10 | AD  -66.20 | BD  -60.10
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/C](-26.541,-1.603,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/A](-4.731,0.026,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/B](-10.831,-0.646,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/D](-70.928,-2.127,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# CA  +25.81 | CB  +14.71 | CD  -37.39 | AB  -11.10 | AD  -63.20 | BD  -52.10    (Iteration  1, r2 =  12497.8)
# CA  +26.81 | CB  +12.71 | CD  -35.39 | AB  -14.10 | AD  -62.20 | BD  -48.10    (Iteration  2, r2 =  12344.1)
# CA  +26.81 | CB  +12.71 | CD  -34.39 | AB  -14.10 | AD  -61.20 | BD  -47.10    (Iteration  3, r2 =  12321.3)
# CA  +26.81 | CB  +12.71 | CD  -33.39 | AB  -14.10 | AD  -60.20 | BD  -46.10    (Iteration  4, r2 =  12302.6)
# CA  +26.81 | CB  +12.71 | CD  -33.39 | AB  -14.10 | AD  -60.20 | BD  -46.10    (Iteration  5, r2 =  12288.4)
# Rough time shifts done :
# CA  +26.81 | CB  +12.71 | CD  -33.39 | AB  -14.10 | AD  -60.20 | BD  -46.10
# Starting opt_fine on initial delays :
# CA  +26.81 | CB  +12.71 | CD  -33.39 | AB  -14.10 | AD  -60.20 | BD  -46.10
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +29.18 | CB  +19.60 | CD  -39.60 | AB   -9.58 | AD  -68.78 | BD  -59.20    (Iteration  1, r2 =   4819.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +29.09 | CB  +21.26 | CD  -39.36 | AB   -7.84 | AD  -68.45 | BD  -60.61    (Iteration  2, r2 =   4059.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +28.75 | CB  +21.55 | CD  -39.20 | AB   -7.20 | AD  -67.95 | BD  -60.74    (Iteration  3, r2 =   3775.8)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +28.43 | CB  +21.63 | CD  -39.09 | AB   -6.80 | AD  -67.52 | BD  -60.72    (Iteration  4, r2 =   3676.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +28.25 | CB  +21.49 | CD  -39.18 | AB   -6.76 | AD  -67.43 | BD  -60.67    (Iteration  5, r2 =   3603.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +28.15 | CB  +21.31 | CD  -39.29 | AB   -6.84 | AD  -67.45 | BD  -60.60    (Iteration  6, r2 =   3565.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +28.11 | CB  +21.27 | CD  -39.21 | AB   -6.84 | AD  -67.32 | BD  -60.48    (Iteration  7, r2 =   3560.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +28.02 | CB  +21.27 | CD  -39.27 | AB   -6.75 | AD  -67.29 | BD  -60.53    (Iteration  8, r2 =   3558.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +27.98 | CB  +21.18 | CD  -39.27 | AB   -6.80 | AD  -67.24 | BD  -60.45    (Iteration  9, r2 =   3535.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# CA  +27.93 | CB  +21.18 | CD  -39.38 | AB   -6.75 | AD  -67.32 | BD  -60.56    (Iteration 10, r2 =   3567.5)
# Timeshift stabilization and releasing of splflat :
# CA  +27.56 | CB  +20.94 | CD  -39.83 | AB   -6.62 | AD  -67.39 | BD  -60.77    (Iteration  1, r2 =   3387.7)
# CA  +27.58 | CB  +20.94 | CD  -39.89 | AB   -6.64 | AD  -67.47 | BD  -60.83    (Iteration  2, r2 =   3364.1)
# CA  +27.58 | CB  +20.94 | CD  -39.95 | AB   -6.64 | AD  -67.53 | BD  -60.88    (Iteration  3, r2 =   3351.5)
# CA  +27.58 | CB  +20.94 | CD  -39.95 | AB   -6.64 | AD  -67.53 | BD  -60.88    (Iteration  4, r2 =   3343.0)
# CA  +27.58 | CB  +20.94 | CD  -39.95 | AB   -6.64 | AD  -67.53 | BD  -60.88    (Iteration  5, r2 =   3337.0)
# Shifted 1 simulations, using 1 CPU, time : 18
# Wrote sims_mocks_opt_spl/2_1475093439.78239_opt.pkl
# Wrote sims_mocks_opt_spl/2_1475093439.78239_runresults.pkl
# --- Casino running on simset mocks, optset spl ---
# Read sims_mocks/3_1475093439.86694.pkl
# Working for sims_mocks_opt_spl/3_1475093439.86694_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# DC  +47.94 | DA  +69.68 | DB  +64.71 | CA  +21.74 | CB  +16.77 | AB   -4.97
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/D](-74.937,-2.092,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/C](-26.996,-1.628,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/A](-5.254,0.003,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/B](-10.226,-0.662,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# DC  +55.94 | DA  +75.68 | DB  +73.71 | CA  +19.74 | CB  +17.77 | AB   -1.97    (Iteration  1, r2 =  10079.3)
# DC  +60.94 | DA  +78.68 | DB  +78.71 | CA  +17.74 | CB  +17.77 | AB   +0.03    (Iteration  2, r2 =   9774.0)
# DC  +64.94 | DA  +80.68 | DB  +81.71 | CA  +15.74 | CB  +16.77 | AB   +1.03    (Iteration  3, r2 =   9598.0)
# DC  +66.94 | DA  +81.68 | DB  +83.71 | CA  +14.74 | CB  +16.77 | AB   +2.03    (Iteration  4, r2 =   9459.9)
# DC  +67.94 | DA  +81.68 | DB  +84.71 | CA  +13.74 | CB  +16.77 | AB   +3.03    (Iteration  5, r2 =   9343.3)
# Rough time shifts done :
# DC  +67.94 | DA  +81.68 | DB  +84.71 | CA  +13.74 | CB  +16.77 | AB   +3.03
# Starting opt_rough on initial delays :
# DC  +67.94 | DA  +81.68 | DB  +84.71 | CA  +13.74 | CB  +16.77 | AB   +3.03
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/D](-91.937,-2.092,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/C](-23.996,-1.628,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/A](-10.254,0.003,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/B](-7.226,-0.662,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# DC  +55.94 | DA  +72.68 | DB  +72.71 | CA  +16.74 | CB  +16.77 | AB   +0.03    (Iteration  1, r2 =   8135.9)
# DC  +53.94 | DA  +70.68 | DB  +69.71 | CA  +16.74 | CB  +15.77 | AB   -0.97    (Iteration  2, r2 =   8083.4)
# DC  +53.94 | DA  +70.68 | DB  +69.71 | CA  +16.74 | CB  +15.77 | AB   -0.97    (Iteration  3, r2 =   8079.2)
# DC  +53.94 | DA  +70.68 | DB  +69.71 | CA  +16.74 | CB  +15.77 | AB   -0.97    (Iteration  4, r2 =   8077.7)
# DC  +53.94 | DA  +70.68 | DB  +69.71 | CA  +16.74 | CB  +15.77 | AB   -0.97    (Iteration  5, r2 =   8076.9)
# Rough time shifts done :
# DC  +53.94 | DA  +70.68 | DB  +69.71 | CA  +16.74 | CB  +15.77 | AB   -0.97
# Starting opt_fine on initial delays :
# DC  +53.94 | DA  +70.68 | DB  +69.71 | CA  +16.74 | CB  +15.77 | AB   -0.97
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.14 | DA  +67.25 | DB  +68.72 | CA  +15.11 | CB  +16.59 | AB   +1.48    (Iteration  1, r2 =   3363.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.00 | DA  +66.87 | DB  +68.73 | CA  +14.88 | CB  +16.73 | AB   +1.86    (Iteration  2, r2 =   3274.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +51.94 | DA  +66.71 | DB  +68.72 | CA  +14.78 | CB  +16.79 | AB   +2.01    (Iteration  3, r2 =   3238.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.52 | DA  +66.71 | DB  +68.73 | CA  +14.19 | CB  +16.21 | AB   +2.02    (Iteration  4, r2 =   3217.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.86 | DA  +66.81 | DB  +68.81 | CA  +13.95 | CB  +15.95 | AB   +2.00    (Iteration  5, r2 =   3223.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.86 | DA  +66.74 | DB  +68.76 | CA  +13.88 | CB  +15.90 | AB   +2.01    (Iteration  6, r2 =   3223.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.84 | DA  +66.77 | DB  +68.71 | CA  +13.93 | CB  +15.86 | AB   +1.94    (Iteration  7, r2 =   3220.4)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.90 | DA  +66.80 | DB  +68.71 | CA  +13.89 | CB  +15.81 | AB   +1.91    (Iteration  8, r2 =   3211.9)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.89 | DA  +66.86 | DB  +68.72 | CA  +13.97 | CB  +15.83 | AB   +1.86    (Iteration  9, r2 =   3215.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# DC  +52.89 | DA  +66.79 | DB  +68.72 | CA  +13.90 | CB  +15.83 | AB   +1.93    (Iteration 10, r2 =   3188.4)
# Timeshift stabilization and releasing of splflat :
# DC  +52.75 | DA  +66.52 | DB  +69.17 | CA  +13.77 | CB  +16.42 | AB   +2.65    (Iteration  1, r2 =   2595.9)
# DC  +52.75 | DA  +66.45 | DB  +69.22 | CA  +13.70 | CB  +16.48 | AB   +2.77    (Iteration  2, r2 =   2592.4)
# DC  +52.75 | DA  +66.41 | DB  +69.22 | CA  +13.67 | CB  +16.48 | AB   +2.81    (Iteration  3, r2 =   2590.6)
# DC  +52.75 | DA  +66.41 | DB  +69.22 | CA  +13.67 | CB  +16.48 | AB   +2.81    (Iteration  4, r2 =   2589.2)
# DC  +52.75 | DA  +66.41 | DB  +69.22 | CA  +13.67 | CB  +16.48 | AB   +2.81    (Iteration  5, r2 =   2588.1)
# Shifted 1 simulations, using 1 CPU, time : 25
# Wrote sims_mocks_opt_spl/3_1475093439.86694_opt.pkl
# Wrote sims_mocks_opt_spl/3_1475093439.86694_runresults.pkl
# --- Casino running on simset mocks, optset spl ---
# Read sims_mocks/4_1475093439.92795.pkl
# Working for sims_mocks_opt_spl/4_1475093439.92795_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting opt_rough on initial delays :
# BD  -63.51 | BA   +4.04 | BC  -15.39 | DA  +67.55 | DC  +48.12 | AC  -19.43
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/B](-10.715,-0.647,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/D](-74.230,-2.036,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/A](-6.678,0.050,0)|~3/12l12b/7~|
# Working on the spline ML of [Trialsim/C](-26.110,-1.613,0)|~3/12l12b/7~|
# Done !
# First spline and ML opt done.
# BD  -71.51 | BA   +2.04 | BC  -13.39 | DA  +73.55 | DC  +58.12 | AC  -15.43    (Iteration  1, r2 =   9519.2)
# BD  -75.51 | BA   +1.04 | BC  -11.39 | DA  +76.55 | DC  +64.12 | AC  -12.43    (Iteration  2, r2 =   9362.7)
# BD  -77.51 | BA   +0.04 | BC  -10.39 | DA  +77.55 | DC  +67.12 | AC  -10.43    (Iteration  3, r2 =   9260.4)
# BD  -79.51 | BA   +0.04 | BC  -10.39 | DA  +79.55 | DC  +69.12 | AC  -10.43    (Iteration  4, r2 =   9248.0)
# BD  -80.51 | BA   -0.96 | BC  -10.39 | DA  +79.55 | DC  +70.12 | AC   -9.43    (Iteration  5, r2 =   9176.1)
# Rough time shifts done :
# BD  -80.51 | BA   -0.96 | BC  -10.39 | DA  +79.55 | DC  +70.12 | AC   -9.43
# Starting opt_rough on initial delays :
# BD  -80.51 | BA   -0.96 | BC  -10.39 | DA  +79.55 | DC  +70.12 | AC   -9.43
# Aiming at first curve.
# Starting ML optimization ...
# Working on the spline ML of [Trialsim/B](-9.715,-0.647,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/D](-90.230,-2.036,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/A](-10.678,0.050,0)|~3/u/7~|
# Working on the spline ML of [Trialsim/C](-20.110,-1.613,0)|~3/u/7~|
# Done !
# First spline and ML opt done.
# BD  -72.51 | BA   +3.04 | BC  -11.39 | DA  +75.55 | DC  +61.12 | AC  -14.43    (Iteration  1, r2 =   7195.5)
# BD  -69.51 | BA   +4.04 | BC  -10.39 | DA  +73.55 | DC  +59.12 | AC  -14.43    (Iteration  2, r2 =   7144.8)
# BD  -68.51 | BA   +4.04 | BC  -11.39 | DA  +72.55 | DC  +57.12 | AC  -15.43    (Iteration  3, r2 =   7133.9)
# BD  -68.51 | BA   +4.04 | BC  -11.39 | DA  +72.55 | DC  +57.12 | AC  -15.43    (Iteration  4, r2 =   7130.8)
# BD  -67.51 | BA   +4.04 | BC  -11.39 | DA  +71.55 | DC  +56.12 | AC  -15.43    (Iteration  5, r2 =   7126.9)
# Rough time shifts done :
# BD  -67.51 | BA   +4.04 | BC  -11.39 | DA  +71.55 | DC  +56.12 | AC  -15.43
# Starting opt_fine on initial delays :
# BD  -67.51 | BA   +4.04 | BC  -11.39 | DA  +71.55 | DC  +56.12 | AC  -15.43
# Iterations :
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -66.96 | BA   +2.46 | BC  -10.89 | DA  +69.42 | DC  +56.07 | AC  -13.35    (Iteration  1, r2 =   3642.2)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -67.21 | BA   +2.27 | BC  -10.96 | DA  +69.48 | DC  +56.25 | AC  -13.23    (Iteration  2, r2 =   3506.7)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -67.15 | BA   +2.40 | BC  -10.84 | DA  +69.55 | DC  +56.31 | AC  -13.24    (Iteration  3, r2 =   3415.5)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -67.23 | BA   +2.38 | BC  -10.95 | DA  +69.61 | DC  +56.28 | AC  -13.32    (Iteration  4, r2 =   3362.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -67.53 | BA   +2.43 | BC  -10.94 | DA  +69.96 | DC  +56.60 | AC  -13.36    (Iteration  5, r2 =   3295.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -67.93 | BA   +2.36 | BC  -11.01 | DA  +70.28 | DC  +56.91 | AC  -13.37    (Iteration  6, r2 =   3278.3)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -68.21 | BA   +2.33 | BC  -11.13 | DA  +70.54 | DC  +57.08 | AC  -13.45    (Iteration  7, r2 =   3246.5)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -68.54 | BA   +2.26 | BC  -11.28 | DA  +70.80 | DC  +57.26 | AC  -13.54    (Iteration  8, r2 =   3263.0)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -68.65 | BA   +2.31 | BC  -11.27 | DA  +70.96 | DC  +57.38 | AC  -13.58    (Iteration  9, r2 =   3247.1)
# Start
# opt_ts_indi brute done
# opt_ts_indi fine done
# opt_ml done
# opt_source BOK done
# BD  -68.74 | BA   +2.32 | BC  -11.31 | DA  +71.06 | DC  +57.43 | AC  -13.62    (Iteration 10, r2 =   3263.3)
# Timeshift stabilization and releasing of splflat :
# BD  -68.99 | BA   +0.94 | BC  -11.94 | DA  +69.93 | DC  +57.05 | AC  -12.88    (Iteration  1, r2 =   2174.7)
# BD  -68.99 | BA   +0.87 | BC  -12.02 | DA  +69.86 | DC  +56.97 | AC  -12.88    (Iteration  2, r2 =   2165.7)
# BD  -68.99 | BA   +0.87 | BC  -12.02 | DA  +69.86 | DC  +56.97 | AC  -12.88    (Iteration  3, r2 =   2162.2)
# BD  -68.99 | BA   +0.87 | BC  -12.02 | DA  +69.86 | DC  +56.97 | AC  -12.88    (Iteration  4, r2 =   2160.2)
# BD  -68.93 | BA   +0.87 | BC  -12.02 | DA  +69.79 | DC  +56.91 | AC  -12.88    (Iteration  5, r2 =   2158.9)
# Shifted 1 simulations, using 1 CPU, time : 26
# Wrote sims_mocks_opt_spl/4_1475093439.92795_opt.pkl
# Wrote sims_mocks_opt_spl/4_1475093439.92795_runresults.pkl

# %% [markdown]
# > Note: The two lines of code above do not (always) run, possibly due to a bug that should be reported to PyCS. Here is the resulting error message.
# >
# > `RuntimeError: Knot spacing min = 7.283257, epsilon = 10.000000`

# %% [markdown]
# ### 4.3 Collecting the Outputs

# %% [markdown]
# First, let's get the results from the copies of the observed light curves.

# %%
dataresults = [
        pycs.sim.run.collect("sims_copies_opt_spl", "blue", "Free-knot spline technique")
]
# Out:
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Free-knot spline technique

# %% [markdown]
# Now, we can turn this into a simple histogram that will give the instrinic variance. It will be saved to a file called "fig_instrinsicvariance.pdf", for readability. The option `dataout=True` will save the delay point estimate, to be used below.

# %%
pycs.sim.plot.hists(dataresults, r=5.0, nbins=100, showqs=False,
        filename="fig_intrinsicvariance.pdf", dataout=True)
# Out:
# Wrote sims_copies_opt_spl_delays.pkl
# Plotting "Free-knot spline technique (Measured, 4) "
#      Labels : A, B, C, D
#      Median shifts : -9.39, -14.39, -30.53, -78.54
#      Std shifts : 2.24, 2.15, 1.96, 1.91

# %% [markdown]
# We read the results obtained on the synthetic curves.

# %%
simresults = [
        pycs.sim.run.collect("sims_mocks_opt_spl", "blue", "Free-knot spline technique")
]
# Out:
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Free-knot spline technique

# %% [markdown]
# Now we can perform the error analysis. This will be saved to a file called "fig_measvstrue.pdf". The option `dataout=True` will save the random and systematic error, to be used below.

# %%
pycs.sim.plot.measvstrue(simresults, errorrange=3.5, r=5.0, nbins = 1, binclip=True, binclipr=20.0,
        plotpoints=False, filename="fig_measvstrue.pdf", dataout=True)
# Out:
# Wrote sims_mocks_opt_spl_errorbars.pkl

# %% [markdown]
# With the same data we can also show the relationship between measurements. This will be written to a file called "fig_covplot.pdf".

# %%
pycs.sim.plot.covplot(simresults, filename="fig_covplot.pdf")

# %% [markdown]
# Finally we group the information saved by these steps to get the results in form of a summary plot. Let's define our variables.

# %%
dataresults = [(pycs.gen.util.readpickle("sims_copies_opt_spl_delays.pkl"),
               pycs.gen.util.readpickle("sims_mocks_opt_spl_errorbars.pkl"))]
# Out:
# Read sims_copies_opt_spl_delays.pkl
# Read sims_mocks_opt_spl_errorbars.pkl

# %% [markdown]
# Now we can display our plot! It will be saved to a file called "fig_delays.pdf".

# %%
pycs.sim.plot.newdelayplot(dataresults, rplot=6.0, displaytext=True,
        filename = "fig_delays.pdf", refshifts=[{"colour":"gray", "shifts":(0, -5, -20, -70)}])
# Out:
# Objects : A, B, C, D
# Delays : Free-knot spline technique <-> Errors : Free-knot spline technique
# ################################################################################
#            Delay AB
#                    Free-knot spline technique :  -5.03 +/- 1.69 (1.04, 1.33)
# ################################################################################
#            Delay AC
#                    Free-knot spline technique : -21.14 +/- 2.48 (1.64, 1.85)
# ################################################################################
#            Delay BC
#                    Free-knot spline technique : -16.10 +/- 2.01 (1.63, 1.18)
# ################################################################################
#            Delay AD
#                    Free-knot spline technique : -69.03 +/- 2.97 (0.00, 2.97)
# ################################################################################
#            Delay BD
#                    Free-knot spline technique : -64.00 +/- 1.51 (1.42, 0.53)
# ################################################################################
#            Delay CD
#                    Free-knot spline technique : -47.89 +/- 1.65 (0.11, 1.65)
# ################################################################################

# %% [markdown]
# ## 5. Comparing Different Curve-shifting Techniques
#
# `PyCS` supports a number of different time delay estimation methods, as well as the free-knot spline curve-shifting model. Let's try a couple more of them now, and compare with the spline model (which we already optimized and explored). We'll start the other two the same way, on the original data and with a reasonable set of guessed initial shifts, for a fair comparison.

# %%
import pycs.regdiff

for l in lcs:
    l.resetshifts()
    
lcs[1].shifttime(-7.0)
lcs[2].shifttime(-22.0)
lcs[3].shifttime(-65.0)

print(pycs.gen.lc.getnicetimedelays(lcs, separator="\n", sorted=True))

def regdiff(lcs):
    return pycs.regdiff.multiopt.opt_ts(lcs, pd=5, scale=200.0, verbose=True)
def disp(lcs):
    return pycs.disp.topopt.opt_full(lcs, rawdispersionmethod, nit=5, verbose=True)
# Out:
# AB   -7.00
# AC  -22.00
# AD  -65.00
# BC  -15.00
# BD  -58.00
# CD  -43.00

# %% [markdown]
# ### 5.1 Dispersion Method
#
# Our second technique will be the dispersion technique. First, let's run the code needed to define our variables.

# %%
rawdispersionmethod = lambda lc1, lc2 : pycs.disp.disps.linintnp(lc1, lc2, interpdist = 30.0)
dispersionmethod = lambda lc1, lc2 : pycs.disp.disps.symmetrize(lc1, lc2, rawdispersionmethod)

# %% [markdown]
# Next, let's factor in our microlensing models (polynomials).

# %%
pycs.gen.polyml.addtolc(lcs[0], nparams=2, autoseasonsgap = 60.0)
pycs.gen.polyml.addtolc(lcs[1], nparams=2, autoseasonsgap = 60.0)
pycs.gen.polyml.addtolc(lcs[2], nparams=2, autoseasonsgap = 60.0)
pycs.gen.polyml.addtolc(lcs[3], nparams=2, autoseasonsgap = 60.0)

# %% [markdown]
# Now we will run using the dispersion technique on our plain copies data, created earlier.

# %%
pycs.sim.run.multirun("copies", lcs, disp, optset="disp", tsrand=10.0)
# Out:
# I have found 4 simulation pickles in sims_copies.
# I'll write my results into the directory sims_copies_opt_disp.
# Initial conditions :
# [Trial/A]|poly/2222|
# [Trial/B](-7.000,0.000,0)|poly/2222|
# [Trial/C](-22.000,0.000,0)|poly/2222|
# [Trial/D](-65.000,0.000,0)|poly/2222|
# --- Casino running on simset copies, optset disp ---
# Read sims_copies/1_1475093439.64908.pkl
# Working for sims_copies_opt_disp/1_1475093439.64908_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trial/B](0.023,0.000,0)|poly/2222|
# [Trial/C](-29.167,0.000,0)|poly/2222|
# [Trial/A](-4.373,0.000,0)|poly/2222|
# [Trial/D](-68.416,0.000,0)|poly/2222|
# Initial delays :
# BC  -29.19 | BA   -4.40 | BD  -68.44 | CA  +24.79 | CD  -39.25 | AD  -64.04
# Iteration 1 done, d2 =    4.408
# BC  -17.99 | BA   +4.64 | BD  -63.59 | CA  +22.63 | CD  -45.60 | AD  -68.23
# Iteration 2 done, d2 =    3.388
# BC  -16.80 | BA   +5.62 | BD  -63.41 | CA  +22.42 | CD  -46.61 | AD  -69.03
# Iteration 3 done, d2 =    3.383
# BC  -16.77 | BA   +5.65 | BD  -63.42 | CA  +22.43 | CD  -46.65 | AD  -69.07
# Iteration 4 done, d2 =    3.383
# BC  -16.77 | BA   +5.65 | BD  -63.42 | CA  +22.43 | CD  -46.65 | AD  -69.07
# Iteration 5 done, d2 =    3.383
# BC  -16.77 | BA   +5.65 | BD  -63.42 | CA  +22.43 | CD  -46.65 | AD  -69.07
# Done with optimization of :
# [Trial/B](0.023,0.000,0)|poly/2222|
# [Trial/C](-16.750,-1.007,0)|poly/2222|
# [Trial/A](5.678,0.797,0)|poly/2222|
# [Trial/D](-63.396,-1.537,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 54
# Wrote sims_copies_opt_disp/1_1475093439.64908_runresults.pkl
# --- Casino running on simset copies, optset disp ---
# Read sims_copies/2_1475093439.65691.pkl
# Working for sims_copies_opt_disp/2_1475093439.65691_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trial/B](-6.341,0.000,0)|poly/2222|
# [Trial/D](-62.200,0.000,0)|poly/2222|
# [Trial/A](9.053,0.000,0)|poly/2222|
# [Trial/C](-21.953,0.000,0)|poly/2222|
# Initial delays :
# BD  -55.86 | BA  +15.39 | BC  -15.61 | DA  +71.25 | DC  +40.25 | AC  -31.01
# Iteration 1 done, d2 =    5.346
# BD  -59.65 | BA   +9.57 | BC  -13.29 | DA  +69.21 | DC  +46.36 | AC  -22.86
# Iteration 2 done, d2 =    3.406
# BD  -61.71 | BA   +6.63 | BC  -15.35 | DA  +68.35 | DC  +46.36 | AC  -21.99
# Iteration 3 done, d2 =    3.391
# BD  -62.10 | BA   +6.56 | BC  -15.58 | DA  +68.66 | DC  +46.53 | AC  -22.14
# Iteration 4 done, d2 =    3.390
# BD  -62.12 | BA   +6.56 | BC  -15.59 | DA  +68.68 | DC  +46.54 | AC  -22.14
# Iteration 5 done, d2 =    3.390
# BD  -62.13 | BA   +6.56 | BC  -15.59 | DA  +68.68 | DC  +46.54 | AC  -22.14
# Done with optimization of :
# [Trial/B](-6.341,0.000,0)|poly/2222|
# [Trial/D](-68.467,-1.538,0)|poly/2222|
# [Trial/A](0.215,0.815,0)|poly/2222|
# [Trial/C](-21.927,-0.999,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 68
# Wrote sims_copies_opt_disp/2_1475093439.65691_runresults.pkl
# --- Casino running on simset copies, optset disp ---
# Read sims_copies/3_1475093439.66198.pkl
# Working for sims_copies_opt_disp/3_1475093439.66198_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trial/D](-60.369,0.000,0)|poly/2222|
# [Trial/B](-14.296,0.000,0)|poly/2222|
# [Trial/A](1.441,0.000,0)|poly/2222|
# [Trial/C](-26.093,0.000,0)|poly/2222|
# Initial delays :
# DB  +46.07 | DA  +61.81 | DC  +34.28 | BA  +15.74 | BC  -11.80 | AC  -27.53
# Iteration 1 done, d2 =    6.126
# DB  +58.67 | DA  +68.25 | DC  +45.51 | BA   +9.58 | BC  -13.16 | AC  -22.74
# Iteration 2 done, d2 =    3.464
# DB  +61.68 | DA  +68.36 | DC  +46.25 | BA   +6.69 | BC  -15.43 | AC  -22.12
# Iteration 3 done, d2 =    3.391
# DB  +62.11 | DA  +68.67 | DC  +46.53 | BA   +6.56 | BC  -15.58 | AC  -22.14
# Iteration 4 done, d2 =    3.390
# DB  +62.13 | DA  +68.68 | DC  +46.54 | BA   +6.56 | BC  -15.59 | AC  -22.14
# Iteration 5 done, d2 =    3.390
# DB  +62.13 | DA  +68.68 | DC  +46.54 | BA   +6.56 | BC  -15.59 | AC  -22.14
# Done with optimization of :
# [Trial/D](-60.369,0.000,0)|poly/2222|
# [Trial/B](1.758,1.532,0)|poly/2222|
# [Trial/A](8.314,2.346,0)|poly/2222|
# [Trial/C](-13.828,0.536,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 53
# Wrote sims_copies_opt_disp/3_1475093439.66198_runresults.pkl
# --- Casino running on simset copies, optset disp ---
# Read sims_copies/4_1475093439.66685.pkl
# Working for sims_copies_opt_disp/4_1475093439.66685_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trial/A](-4.660,0.000,0)|poly/2222|
# [Trial/B](-5.191,0.000,0)|poly/2222|
# [Trial/D](-56.787,0.000,0)|poly/2222|
# [Trial/C](-17.484,0.000,0)|poly/2222|
# Initial delays :
# AB   -0.53 | AD  -52.13 | AC  -12.82 | BD  -51.60 | BC  -12.29 | DC  +39.30
# Iteration 1 done, d2 =    3.682
# AB   -6.51 | AD  -67.47 | AC  -21.26 | BD  -60.96 | BC  -14.75 | DC  +46.21
# Iteration 2 done, d2 =    3.400
# AB   -6.58 | AD  -68.31 | AC  -21.96 | BD  -61.73 | BC  -15.38 | DC  +46.35
# Iteration 3 done, d2 =    3.391
# AB   -6.56 | AD  -68.66 | AC  -22.14 | BD  -62.11 | BC  -15.58 | DC  +46.53
# Iteration 4 done, d2 =    3.389
# AB   -5.69 | AD  -69.06 | AC  -22.42 | BD  -63.38 | BC  -16.73 | DC  +46.65
# Iteration 5 done, d2 =    3.383
# AB   -5.65 | AD  -69.07 | AC  -22.42 | BD  -63.42 | BC  -16.77 | DC  +46.65
# Done with optimization of :
# [Trial/A](-4.660,0.000,0)|poly/2222|
# [Trial/B](-10.310,-0.794,0)|poly/2222|
# [Trial/D](-73.729,-2.331,0)|poly/2222|
# [Trial/C](-27.084,-1.804,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 64
# Wrote sims_copies_opt_disp/4_1475093439.66685_runresults.pkl

# %% [markdown]
# And now we will run the dispersion technique on our synthetic light curve data.

# %%
pycs.sim.run.multirun("mocks", lcs, disp, optset="disp", tsrand=10.0)
# Out:
# I have found 4 simulation pickles in sims_mocks.
# I'll write my results into the directory sims_mocks_opt_disp.
# Initial conditions :
# [Trial/A]|poly/2222|
# [Trial/B](-7.000,0.000,0)|poly/2222|
# [Trial/C](-22.000,0.000,0)|poly/2222|
# [Trial/D](-65.000,0.000,0)|poly/2222|
# --- Casino running on simset mocks, optset disp ---
# Read sims_mocks/1_1475093439.70907.pkl
# Working for sims_mocks_opt_disp/1_1475093439.70907_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trialsim/C](-29.321,0.000,0)|poly/2222|
# [Trialsim/B](-7.521,0.000,0)|poly/2222|
# [Trialsim/A](8.835,0.000,0)|poly/2222|
# [Trialsim/D](-64.565,0.000,0)|poly/2222|
# Initial delays :
# CB  +21.80 | CA  +38.16 | CD  -35.24 | BA  +16.36 | BD  -57.04 | AD  -73.40
# Iteration 1 done, d2 =    5.034
# CB   +8.67 | CA  +29.14 | CD  -52.42 | BA  +20.47 | BD  -61.09 | AD  -81.56
# Iteration 2 done, d2 =    3.159
# CB   +5.70 | CA  +26.27 | CD  -57.28 | BA  +20.57 | BD  -62.98 | AD  -83.56
# Iteration 3 done, d2 =    3.111
# CB   +4.70 | CA  +25.14 | CD  -58.56 | BA  +20.44 | BD  -63.26 | AD  -83.71
# Iteration 4 done, d2 =    3.094
# CB   +3.12 | CA  +23.47 | CD  -60.21 | BA  +20.35 | BD  -63.33 | AD  -83.68
# Iteration 5 done, d2 =    3.083
# CB   +3.02 | CA  +23.37 | CD  -60.29 | BA  +20.36 | BD  -63.31 | AD  -83.67
# Done with optimization of :
# [Trialsim/C](-29.321,0.000,0)|poly/2222|
# [Trialsim/B](-26.305,1.028,0)|poly/2222|
# [Trialsim/A](-5.948,1.829,0)|poly/2222|
# [Trialsim/D](-89.614,-0.518,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 54
# Wrote sims_mocks_opt_disp/1_1475093439.70907_runresults.pkl
# --- Casino running on simset mocks, optset disp ---
# Read sims_mocks/2_1475093439.78239.pkl
# Working for sims_mocks_opt_disp/2_1475093439.78239_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trialsim/D](-73.015,0.000,0)|poly/2222|
# [Trialsim/A](0.056,0.000,0)|poly/2222|
# [Trialsim/C](-13.360,0.000,0)|poly/2222|
# [Trialsim/B](-14.221,0.000,0)|poly/2222|
# Initial delays :
# DA  +73.07 | DC  +59.65 | DB  +58.79 | AC  -13.42 | AB  -14.28 | CB   -0.86
# Iteration 1 done, d2 =    7.961
# DA  +68.82 | DC  +41.14 | DB  +60.40 | AC  -27.68 | AB   -8.42 | CB  +19.26
# Iteration 2 done, d2 =    6.471
# DA  +67.58 | DC  +39.00 | DB  +60.28 | AC  -28.58 | AB   -7.30 | CB  +21.28
# Iteration 3 done, d2 =    6.449
# DA  +67.40 | DC  +38.81 | DB  +60.14 | AC  -28.59 | AB   -7.27 | CB  +21.33
# Iteration 4 done, d2 =    6.449
# DA  +67.40 | DC  +38.81 | DB  +60.14 | AC  -28.59 | AB   -7.27 | CB  +21.33
# Iteration 5 done, d2 =    6.449
# DA  +67.40 | DC  +38.81 | DB  +60.14 | AC  -28.59 | AB   -7.27 | CB  +21.33
# Done with optimization of :
# [Trialsim/D](-73.015,0.000,0)|poly/2222|
# [Trialsim/A](-5.614,2.354,0)|poly/2222|
# [Trialsim/C](-34.205,0.549,0)|poly/2222|
# [Trialsim/B](-12.880,1.551,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 71
# Wrote sims_mocks_opt_disp/2_1475093439.78239_runresults.pkl
# --- Casino running on simset mocks, optset disp ---
# Read sims_mocks/3_1475093439.86694.pkl
# Working for sims_mocks_opt_disp/3_1475093439.86694_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trialsim/B](-8.712,0.000,0)|poly/2222|
# [Trialsim/C](-18.365,0.000,0)|poly/2222|
# [Trialsim/D](-70.752,0.000,0)|poly/2222|
# [Trialsim/A](-1.249,0.000,0)|poly/2222|
# Initial delays :
# BC   -9.65 | BD  -62.04 | BA   +7.46 | CD  -52.39 | CA  +17.12 | DA  +69.50
# Iteration 1 done, d2 =    4.296
# BC  -15.66 | BD  -68.38 | BA   -1.33 | CD  -52.72 | CA  +14.33 | DA  +67.05
# Iteration 2 done, d2 =    3.549
# BC  -16.52 | BD  -68.58 | BA   -2.25 | CD  -52.06 | CA  +14.26 | DA  +66.33
# Iteration 3 done, d2 =    3.539
# BC  -16.55 | BD  -68.60 | BA   -2.29 | CD  -52.05 | CA  +14.26 | DA  +66.31
# Iteration 4 done, d2 =    3.539
# BC  -16.55 | BD  -68.60 | BA   -2.29 | CD  -52.05 | CA  +14.26 | DA  +66.31
# Iteration 5 done, d2 =    3.539
# BC  -16.55 | BD  -68.60 | BA   -2.29 | CD  -52.05 | CA  +14.26 | DA  +66.31
# Done with optimization of :
# [Trialsim/B](-8.712,0.000,0)|poly/2222|
# [Trialsim/C](-25.262,-0.992,0)|poly/2222|
# [Trialsim/D](-77.314,-1.545,0)|poly/2222|
# [Trialsim/A](-11.004,0.806,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 66
# Wrote sims_mocks_opt_disp/3_1475093439.86694_runresults.pkl
# --- Casino running on simset mocks, optset disp ---
# Read sims_mocks/4_1475093439.92795.pkl
# Working for sims_mocks_opt_disp/4_1475093439.92795_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting dispersion optimization of :
# [Trialsim/A](5.772,0.000,0)|poly/2222|
# [Trialsim/C](-31.289,0.000,0)|poly/2222|
# [Trialsim/D](-61.545,0.000,0)|poly/2222|
# [Trialsim/B](-11.386,0.000,0)|poly/2222|
# Initial delays :
# AC  -37.06 | AD  -67.32 | AB  -17.16 | CD  -30.26 | CB  +19.90 | DB  +50.16
# Iteration 1 done, d2 =    5.970
# AC  -18.19 | AD  -69.05 | AB   -5.66 | CD  -50.86 | CB  +12.54 | DB  +63.40
# Iteration 2 done, d2 =    4.212
# AC  -12.78 | AD  -67.06 | AB   -2.50 | CD  -54.29 | CB  +10.28 | DB  +64.56
# Iteration 3 done, d2 =    4.156
# AC  -12.66 | AD  -66.98 | AB   -2.40 | CD  -54.32 | CB  +10.26 | DB  +64.58
# Iteration 4 done, d2 =    4.156
# AC  -12.66 | AD  -66.98 | AB   -2.40 | CD  -54.32 | CB  +10.27 | DB  +64.58
# Iteration 5 done, d2 =    4.156
# AC  -12.66 | AD  -66.98 | AB   -2.40 | CD  -54.32 | CB  +10.27 | DB  +64.58
# Done with optimization of :
# [Trialsim/A](5.772,0.000,0)|poly/2222|
# [Trialsim/C](-6.889,-1.810,0)|poly/2222|
# [Trialsim/D](-61.205,-2.344,0)|poly/2222|
# [Trialsim/B](3.377,-0.830,0)|poly/2222|
# Shifted 1 simulations, using 1 CPU, time : 56
# Wrote sims_mocks_opt_disp/4_1475093439.92795_runresults.pkl

# %% [markdown]
# ### 5.2 Regression Difference Method
#
# First we run the regression difference technique on our plain copies data, created earlier.

# %%
pycs.sim.run.multirun("copies", lcs, regdiff, optset="regdiff", tsrand=10.0)
# Out:
# I have found 4 simulation pickles in sims_copies.
# I'll write my results into the directory sims_copies_opt_regdiff.
# Initial conditions :
# [Trial/A]|poly/2222|
# [Trial/B](-7.000,0.000,0)|poly/2222|
# [Trial/C](-22.000,0.000,0)|poly/2222|
# [Trial/D](-65.000,0.000,0)|poly/2222|
# --- Casino running on simset copies, optset regdiff ---
# Read sims_copies/1_1475093439.64908.pkl
# Working for sims_copies_opt_regdiff/1_1475093439.64908_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# DC  +49.95 | DA  +64.57 | DB  +67.06 | CA  +14.62 | CB  +17.11 | AB   +2.49
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [-19.92799912  -5.30924041  -2.81542624]
# Brute 1 shifts : [-19.92799912  -0.30924041  -2.81542624]
# Brute 1 errorfct : 0.004803
# Brute 2 shifts : [-19.92799912   2.19075959  -2.81542624]
# Brute 2 errorfct : 0.004771
# Brute 3 shifts : [-19.92799912   0.94075959  -4.06542624]
# Brute 3 errorfct : 0.004761
# Brute 4 shifts : [-20.42799912   0.94075959  -4.06542624]
# Brute 4 errorfct : 0.004760
# Optimization terminated successfully.
#          Current function value: 0.004760
#          Iterations: 1
#          Function evaluations: 35
# Final shifts : [-20.34411854   0.8200643   -4.09694166]
# Final errorfct : 0.004760
# Optimization done ! Optimal time delays :
# DC  +49.53 | DA  +70.70 | DB  +65.78 | CA  +21.16 | CB  +16.25 | AB   -4.92
# Shifted 1 simulations, using 1 CPU, time : 14
# Wrote sims_copies_opt_regdiff/1_1475093439.64908_runresults.pkl
# --- Casino running on simset copies, optset regdiff ---
# Read sims_copies/2_1475093439.65691.pkl
# Working for sims_copies_opt_regdiff/2_1475093439.65691_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# BC  -25.44 | BA   -6.86 | BD  -70.87 | CA  +18.58 | CD  -45.43 | AD  -64.01
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [-22.9622905   -4.38014049 -68.38896898]
# Brute 1 shifts : [-12.9622905    5.61985951 -63.38896898]
# Brute 1 errorfct : 0.004805
# Brute 2 shifts : [-12.9622905    8.11985951 -63.38896898]
# Brute 2 errorfct : 0.004765
# Brute 3 shifts : [-14.2122905    6.86985951 -63.38896898]
# Brute 3 errorfct : 0.004763
# Brute 4 shifts : [-13.7122905    7.36985951 -63.38896898]
# Brute 4 errorfct : 0.004760
# Optimization terminated successfully.
#          Current function value: 0.004760
#          Iterations: 1
#          Function evaluations: 43
# Final shifts : [-13.77639118   7.38025387 -63.39383005]
# Final errorfct : 0.004760
# Optimization done ! Optimal time delays :
# BC  -16.26 | BA   +4.90 | BD  -65.87 | CA  +21.16 | CD  -49.62 | AD  -70.77
# Shifted 1 simulations, using 1 CPU, time : 14
# Wrote sims_copies_opt_regdiff/2_1475093439.65691_runresults.pkl
# --- Casino running on simset copies, optset regdiff ---
# Read sims_copies/3_1475093439.66198.pkl
# Working for sims_copies_opt_regdiff/3_1475093439.66198_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# BC  -12.72 | BA   +6.49 | BD  -63.07 | CA  +19.22 | CD  -50.35 | AD  -69.57
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [-12.01621476   7.20210855 -62.36559624]
# Brute 1 shifts : [-12.01621476   7.20210855 -62.36559624]
# Brute 1 errorfct : 0.004830
# Brute 2 shifts : [-14.51621476   7.20210855 -64.86559624]
# Brute 2 errorfct : 0.004781
# Brute 3 shifts : [-15.76621476   5.95210855 -64.86559624]
# Brute 3 errorfct : 0.004762
# Brute 4 shifts : [-15.76621476   5.45210855 -65.36559624]
# Brute 4 errorfct : 0.004760
# Optimization terminated successfully.
#          Current function value: 0.004760
#          Iterations: 1
#          Function evaluations: 34
# Final shifts : [-15.6346683    5.61930491 -65.17437696]
# Final errorfct : 0.004760
# Optimization done ! Optimal time delays :
# BC  -16.34 | BA   +4.91 | BD  -65.88 | CA  +21.25 | CD  -49.54 | AD  -70.79
# Shifted 1 simulations, using 1 CPU, time : 13
# Wrote sims_copies_opt_regdiff/3_1475093439.66198_runresults.pkl
# --- Casino running on simset copies, optset regdiff ---
# Read sims_copies/4_1475093439.66685.pkl
# Working for sims_copies_opt_regdiff/4_1475093439.66685_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# DA  +64.03 | DC  +29.38 | DB  +57.97 | AC  -34.64 | AB   -6.06 | CB  +28.58
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [  6.33658383 -28.30555436   0.27810032]
# Brute 1 shifts : [ 11.33658383 -13.30555436   5.27810032]
# Brute 1 errorfct : 0.004923
# Brute 2 shifts : [ 13.83658383  -8.30555436   7.77810032]
# Brute 2 errorfct : 0.004771
# Brute 3 shifts : [ 12.58658383  -8.30555436   7.77810032]
# Brute 3 errorfct : 0.004761
# Brute 4 shifts : [ 13.08658383  -7.80555436   8.27810032]
# Brute 4 errorfct : 0.004760
# Optimization terminated successfully.
#          Current function value: 0.004760
#          Iterations: 2
#          Function evaluations: 74
# Final shifts : [ 13.19815221  -8.04333838   8.25194468]
# Final errorfct : 0.004760
# Optimization done ! Optimal time delays :
# DA  +70.89 | DC  +49.65 | DB  +65.94 | AC  -21.24 | AB   -4.95 | CB  +16.30
# Shifted 1 simulations, using 1 CPU, time : 13
# Wrote sims_copies_opt_regdiff/4_1475093439.66685_runresults.pkl

# %% [markdown]
# And then we run the regression difference technique on our synthetic light curve data.

# %%
pycs.sim.run.multirun("mocks", lcs, regdiff, optset="regdiff", tsrand=10.0)
# Out:
# I have found 4 simulation pickles in sims_mocks.
# I'll write my results into the directory sims_mocks_opt_regdiff.
# Initial conditions :
# [Trial/A]|poly/2222|
# [Trial/B](-7.000,0.000,0)|poly/2222|
# [Trial/C](-22.000,0.000,0)|poly/2222|
# [Trial/D](-65.000,0.000,0)|poly/2222|
# --- Casino running on simset mocks, optset regdiff ---
# Read sims_mocks/1_1475093439.70907.pkl
# Working for sims_mocks_opt_regdiff/1_1475093439.70907_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# CB   +9.50 | CA   +8.46 | CD  -47.71 | BA   -1.04 | BD  -57.21 | AD  -56.17
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [ -8.43548511  -9.47862165 -65.65040244]
# Brute 1 shifts : [-13.43548511   5.52137835 -80.65040244]
# Brute 1 errorfct : 0.004619
# Brute 2 shifts : [-13.43548511   5.52137835 -78.15040244]
# Brute 2 errorfct : 0.004545
# Brute 3 shifts : [-12.18548511   6.77137835 -76.90040244]
# Brute 3 errorfct : 0.004531
# Brute 4 shifts : [-12.18548511   6.77137835 -77.40040244]
# Brute 4 errorfct : 0.004527
# Optimization terminated successfully.
#          Current function value: 0.004527
#          Iterations: 1
#          Function evaluations: 42
# Final shifts : [-12.18612609   6.72406229 -77.43969933]
# Final errorfct : 0.004527
# Optimization done ! Optimal time delays :
# CB   +5.75 | CA  +24.66 | CD  -59.50 | BA  +18.91 | BD  -65.25 | AD  -84.16
# Shifted 1 simulations, using 1 CPU, time : 13
# Wrote sims_mocks_opt_regdiff/1_1475093439.70907_runresults.pkl
# --- Casino running on simset mocks, optset regdiff ---
# Read sims_mocks/2_1475093439.78239.pkl
# Working for sims_mocks_opt_regdiff/2_1475093439.78239_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# AD  -69.91 | AC  -25.28 | AB   +2.02 | DC  +44.63 | DB  +71.92 | CB  +27.29
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [-69.01222733 -24.38554049   2.90852053]
# Brute 1 shifts : [-69.01222733 -29.38554049  -7.09147947]
# Brute 1 errorfct : 0.005463
# Brute 2 shifts : [-69.01222733 -26.88554049  -4.59147947]
# Brute 2 errorfct : 0.005382
# Brute 3 shifts : [-67.76222733 -26.88554049  -4.59147947]
# Brute 3 errorfct : 0.005370
# Brute 4 shifts : [-67.76222733 -26.88554049  -4.59147947]
# Brute 4 errorfct : 0.005370
# Optimization terminated successfully.
#          Current function value: 0.005370
#          Iterations: 1
#          Function evaluations: 48
# Final shifts : [-67.75494244 -26.92241233  -4.61685892]
# Final errorfct : 0.005370
# Optimization done ! Optimal time delays :
# AD  -68.65 | AC  -27.82 | AB   -5.51 | DC  +40.83 | DB  +63.14 | CB  +22.31
# Shifted 1 simulations, using 1 CPU, time : 14
# Wrote sims_mocks_opt_regdiff/2_1475093439.78239_runresults.pkl
# --- Casino running on simset mocks, optset regdiff ---
# Read sims_mocks/3_1475093439.86694.pkl
# Working for sims_mocks_opt_regdiff/3_1475093439.86694_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# BD  -64.34 | BA   +2.53 | BC   -3.34 | DA  +66.87 | DC  +61.00 | AC   -5.87
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [-74.40852468  -7.53931084 -13.40531677]
# Brute 1 shifts : [-79.40852468 -12.53931084 -28.40531677]
# Brute 1 errorfct : 0.004961
# Brute 2 shifts : [-81.90852468 -15.03931084 -28.40531677]
# Brute 2 errorfct : 0.004871
# Brute 3 shifts : [-80.65852468 -13.78931084 -27.15531677]
# Brute 3 errorfct : 0.004849
# Brute 4 shifts : [-80.65852468 -14.28931084 -27.65531677]
# Brute 4 errorfct : 0.004841
# Optimization terminated successfully.
#          Current function value: 0.004840
#          Iterations: 2
#          Function evaluations: 77
# Final shifts : [-80.47841869 -14.15671513 -27.70549455]
# Final errorfct : 0.004840
# Optimization done ! Optimal time delays :
# BD  -70.41 | BA   -4.09 | BC  -17.64 | DA  +66.32 | DC  +52.77 | AC  -13.55
# Shifted 1 simulations, using 1 CPU, time : 16
# Wrote sims_mocks_opt_regdiff/3_1475093439.86694_runresults.pkl
# --- Casino running on simset mocks, optset regdiff ---
# Read sims_mocks/4_1475093439.92795.pkl
# Working for sims_mocks_opt_regdiff/4_1475093439.92795_runresults.pkl, 1 simulations.
# Starting the curve shifting on a single CPU, no multiprocessing...
# Starting regdiff opt_ts, initial time delays :
# CB  +18.48 | CD  -42.91 | CA  +11.29 | BD  -61.40 | BA   -7.19 | DA  +54.21
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Computing GPR with params pow=1.5, amp=2.0, scale=200.0, errscale=5.0
# Regressions done.
# Starting time shift optimization ...
# Initial pars (shifts, not delays) :  [ -2.68386837 -64.08279324  -9.8768471 ]
# Brute 1 shifts : [-12.68386837 -79.08279324  -9.8768471 ]
# Brute 1 errorfct : 0.004786
# Brute 2 shifts : [-12.68386837 -79.08279324  -9.8768471 ]
# Brute 2 errorfct : 0.004786
# Brute 3 shifts : [-12.68386837 -79.08279324  -9.8768471 ]
# Brute 3 errorfct : 0.004786
# Brute 4 shifts : [-12.18386837 -79.08279324  -9.8768471 ]
# Brute 4 errorfct : 0.004778
# Optimization terminated successfully.
#          Current function value: 0.004777
#          Iterations: 2
#          Function evaluations: 69
# Final shifts : [-12.15442852 -79.1496621   -9.82207462]
# Final errorfct : 0.004777
# Optimization done ! Optimal time delays :
# CB   +9.01 | CD  -57.98 | CA  +11.35 | BD  -67.00 | BA   +2.33 | DA  +69.33
# Shifted 1 simulations, using 1 CPU, time : 15
# Wrote sims_mocks_opt_regdiff/4_1475093439.92795_runresults.pkl

# %% [markdown]
# ###  5.3. Method Comparison
# Let's repeat the collection and plotting steps from above, but now showing all three methods.

# %%
dataresults = [
        pycs.sim.run.collect("sims_copies_opt_spl", "blue", "Free-knot spline technique"),
        pycs.sim.run.collect("sims_copies_opt_disp", "red", "Dispersion-like technique"),
        pycs.sim.run.collect("sims_copies_opt_regdiff", "green", "Regression difference technique")
]
# Out:
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Free-knot spline technique
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Dispersion-like technique
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Regression difference technique

# %%
pycs.sim.plot.hists(dataresults, r=5.0, nbins=100, showqs=False,
        filename="fig_intrinsicvariance.pdf", dataout=True)
# Out:
# Wrote sims_copies_opt_spl_delays.pkl
# Wrote sims_copies_opt_disp_delays.pkl
# Wrote sims_copies_opt_regdiff_delays.pkl
# Plotting "Free-knot spline technique (Measured, 4) "
#      Labels : A, B, C, D
#      Median shifts : -9.39, -14.39, -30.53, -78.54
#      Std shifts : 2.24, 2.15, 1.96, 1.91
# Plotting "Dispersion-like technique (Measured, 4) "
#      Labels : A, B, C, D
#      Median shifts : 2.95, -3.16, -19.34, -65.93
#      Std shifts : 5.01, 4.86, 5.06, 5.08
# Plotting "Regression difference technique (Measured, 4) "
#      Labels : A, B, C, D
#      Median shifts : 6.50, 1.59, -14.71, -64.28
#      Std shifts : 4.43, 4.42, 4.41, 4.36

# %%
simresults = [        
    pycs.sim.run.collect("sims_mocks_opt_spl", "blue", "Free-knot spline technique"),
    pycs.sim.run.collect("sims_mocks_opt_disp", "red", "Dispersion-like technique"),
    pycs.sim.run.collect("sims_mocks_opt_regdiff", "green", "Regression difference technique")
]
# Out:
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Free-knot spline technique
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Dispersion-like technique
# Reading 4 runresult pickles...
# OK, I have collected 4 runs from Regression difference technique

# %%
pycs.sim.plot.measvstrue(simresults, errorrange=3.5, r=5.0, nbins = 1, binclip=True, binclipr=20.0,
        plotpoints=False, filename="fig_measvstrue.pdf", dataout=True)
# Out:
# Wrote sims_mocks_opt_spl_errorbars.pkl
# Wrote sims_mocks_opt_disp_errorbars.pkl
# Wrote sims_mocks_opt_regdiff_errorbars.pkl

# %%
pycs.sim.plot.covplot(simresults, filename="fig_covplot.pdf")

# %%
disp = (pycs.gen.util.readpickle("sims_copies_opt_disp_delays.pkl"),
        pycs.gen.util.readpickle("sims_mocks_opt_disp_errorbars.pkl"))

regdiff = (pycs.gen.util.readpickle("sims_copies_opt_regdiff_delays.pkl"),
        pycs.gen.util.readpickle("sims_mocks_opt_regdiff_errorbars.pkl"))

spl = (pycs.gen.util.readpickle("sims_copies_opt_spl_delays.pkl"),
       pycs.gen.util.readpickle("sims_mocks_opt_spl_errorbars.pkl"))
# Out:
# Read sims_copies_opt_disp_delays.pkl
# Read sims_mocks_opt_disp_errorbars.pkl
# Read sims_copies_opt_regdiff_delays.pkl
# Read sims_mocks_opt_regdiff_errorbars.pkl
# Read sims_copies_opt_spl_delays.pkl
# Read sims_mocks_opt_spl_errorbars.pkl

# %% [markdown]
# Our final plot! Again, over-writing ("fig_delays.pdf"), but summarizing the performance of the three methods.

# %%
pycs.sim.plot.newdelayplot([disp, regdiff, spl], rplot=6.0, displaytext=True,
        filename = "fig_delays.pdf", refshifts=[{"colour":"gray", "shifts":(0, -5, -20, -70)}])
# Out:
# Objects : A, B, C, D
# Delays : Dispersion-like technique <-> Errors : Dispersion-like technique
# Delays : Regression difference technique <-> Errors : Regression difference technique
# Delays : Free-knot spline technique <-> Errors : Free-knot spline technique
# ################################################################################
#            Delay AB
#                     Dispersion-like technique :  -6.10 +/- 1.52 (1.50, 0.25)
#               Regression difference technique :  -4.92 +/- 2.62 (2.34, 1.16)
#                    Free-knot spline technique :  -5.03 +/- 1.69 (1.04, 1.33)
# ################################################################################
#            Delay AC
#                     Dispersion-like technique : -22.28 +/- 1.52 (0.60, 1.40)
#               Regression difference technique : -21.20 +/- 2.33 (1.60, 1.69)
#                    Free-knot spline technique : -21.14 +/- 2.48 (1.64, 1.85)
# ################################################################################
#            Delay BC
#                     Dispersion-like technique : -16.18 +/- 0.79 (0.71, 0.34)
#               Regression difference technique : -16.29 +/- 0.52 (0.46, 0.26)
#                    Free-knot spline technique : -16.10 +/- 2.01 (1.63, 1.18)
# ################################################################################
#            Delay AD
#                     Dispersion-like technique : -68.88 +/- 3.10 (0.00, 3.10)
#               Regression difference technique : -70.79 +/- 1.85 (0.00, 1.85)
#                    Free-knot spline technique : -69.03 +/- 2.97 (0.00, 2.97)
# ################################################################################
#            Delay BD
#                     Dispersion-like technique : -62.77 +/- 2.62 (0.57, 2.56)
#               Regression difference technique : -65.87 +/- 0.71 (0.50, 0.50)
#                    Free-knot spline technique : -64.00 +/- 1.51 (1.42, 0.53)
# ################################################################################
#            Delay CD
#                     Dispersion-like technique : -46.59 +/- 3.40 (0.84, 3.30)
#               Regression difference technique : -49.58 +/- 1.27 (0.63, 1.10)
#                    Free-knot spline technique : -47.89 +/- 1.65 (0.11, 1.65)
# ################################################################################
